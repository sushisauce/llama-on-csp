# %%
# !huggingface-cli login --token <token>
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from datasets import load_dataset
from random import randrange

# Load dataset from the hub
dataset = load_dataset("databricks/databricks-dolly-15k", split="train")

print(f"dataset size: {len(dataset)}")
print(dataset[randrange(len(dataset))])
# dataset size: 15011
# Out:
# Downloading readme: 100%|██████████| 8.20k/8.20k [00:00<00:00, 8.58MB/s]
# Downloading and preparing dataset json/databricks--databricks-dolly-15k to /root/.cache/huggingface/datasets/databricks___json/databricks--databricks-dolly-15k-7427aa6e57c34282/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/13.1M [00:00<?, ?B/s]
# Downloading data: 100%|██████████| 13.1M/13.1M [00:00<00:00, 123MB/s]
# Downloading data files: 100%|██████████| 1/1 [00:00<00:00,  3.73it/s]
# Extracting data files: 100%|██████████| 1/1 [00:00<00:00, 1484.71it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/databricks___json/databricks--databricks-dolly-15k-7427aa6e57c34282/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4. Subsequent calls will reuse this data.
# dataset size: 15011
# {'instruction': 'What types of bikes are there?', 'context': '', 'response': 'There are gravel bikes, road bikes, mountain bikes, BMX bikes, recumbent bikes, unicycles, hybrid bikes, electric bikes, cruiser bikes, trail bikes, CX bikes, enduro bikes, touring bikes, fixed gear bikes, kids bikes, fat bikes, tandem bikes, folding bikes, trikes and low rider bikes.', 'category': 'classification'}

# %%
def format_dolly(sample):
    instruction = f"### Instruction\n{sample['instruction']}"
    context = f"### Context\n{sample['context']}" if len(sample["context"]) > 0 else None
    response = f"### Answer\n{sample['response']}"
    # join all the parts together
    prompt = "\n\n".join([i for i in [instruction, context, response] if i is not None])
    return prompt

# %%
from random import randrange

print(format_dolly(dataset[randrange(len(dataset))]))
# Out:
# ### Instruction
# Make me a list of the oldest board games that I might not know about, and where they were invented.
#
# ### Answer
# Here is a list of some of the oldest board games. Senet (Egypt), The Royal Game of Ur (Iraq), The Lewis Chessmen (Scotland), Mahjong (China), Game of Goose (Scotland) and Pachisi (India).

# %%
from transformers import AutoTokenizer

model_id = "meta-llama/Llama-2-13b-hf" # sharded weights
tokenizer = AutoTokenizer.from_pretrained(model_id,use_auth_token=True)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1714: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(

# %%
from random import randint
from itertools import chain
from functools import partial


# template dataset to add prompt to each sample
def template_dataset(sample):
    sample["text"] = f"{format_dolly(sample)}{tokenizer.eos_token}"
    return sample


# apply prompt template per sample
dataset = dataset.map(template_dataset, remove_columns=list(dataset.features))
# print random sample
print(dataset[randint(0, len(dataset))]["text"])

# empty list to save remainder from batches to use in next batch
remainder = {"input_ids": [], "attention_mask": [], "token_type_ids": []}

def chunk(sample, chunk_length=2048):
    # define global remainder variable to save remainder from batches to use in next batch
    global remainder
    # Concatenate all texts and add remainder from previous batch
    concatenated_examples = {k: list(chain(*sample[k])) for k in sample.keys()}
    concatenated_examples = {k: remainder[k] + concatenated_examples[k] for k in concatenated_examples.keys()}
    # get total number of tokens for batch
    batch_total_length = len(concatenated_examples[list(sample.keys())[0]])

    # get max number of chunks for batch
    if batch_total_length >= chunk_length:
        batch_chunk_length = (batch_total_length // chunk_length) * chunk_length

    # Split by chunks of max_len.
    result = {
        k: [t[i : i + chunk_length] for i in range(0, batch_chunk_length, chunk_length)]
        for k, t in concatenated_examples.items()
    }
    # add remainder to global variable for next batch
    remainder = {k: concatenated_examples[k][batch_chunk_length:] for k in concatenated_examples.keys()}
    # prepare labels
    result["labels"] = result["input_ids"].copy()
    return result


# tokenize and chunk dataset
lm_dataset = dataset.map(
    lambda sample: tokenizer(sample["text"]), batched=True, remove_columns=list(dataset.features)
).map(
    partial(chunk, chunk_length=2048),
    batched=True,
)

# Print total number of samples
print(f"Total number of samples: {len(lm_dataset)}")
# Out:
# ### Instruction
# What are the general rules of the Baseball?
#
# ### Context
# Baseball is played between two teams with nine players in the field from the team that is not batting at that point (the batting team would have one batter in play at "home plate" on the field). On a baseball field, the game is under the authority of several umpires. There are usually four umpires in major league games; up to six (and as few as one) may officiate depending on the league and the importance of the game. There are three bases. Numbered counterclockwise, first, second, and third bases are cushions (sometimes informally referred to as bags) shaped as 15 in (38 cm) squares which are raised a short distance above the ground; together with home plate, the fourth "base", they form a square with sides of 90 ft (27.4 m) called the diamond. Home plate is a pentagonal rubber slab 17 in (43.2 cm) wide. The playing field is divided into three main sections:
#
# The infield, containing the four bases, is for general defensive purposes bounded by the foul lines and within the grass line (see figure).
# The outfield is the grassed area beyond the infield grass line between the foul lines and bounded by a wall or fence.
# Foul territory is the entire area outside the foul lines.
# The pitcher's mound is located in the center of the infield. It is an 18 ft (5.5 m) diameter mound of dirt no higher than 10 in (25.4 cm). Near the center of the mound is the pitching rubber, a rubber slab positioned 60 ft 6 in (18.4 m) from home plate. The pitcher must have one foot on the rubber at the start of every pitch to a batter, but the pitcher may leave the mound area once the ball is released.
#
# At the college/professional level, baseball is played in nine innings in which each team gets one turn to bat and tries to score runs while the other pitches and defends in the field. High school baseball plays seven innings and Little League uses six-inning games. An inning is broken up into two halves in which the away team bats in the top (first) half, and the home team bats in the bottom (second) half. In baseball, the defense always has the ball—a fact that differentiates it from most other team sports. The teams switch every time the defending team gets three players of the batting team out. The winner is the team with the most runs after nine innings. If the home team is ahead after the top of the ninth, play does not continue into the bottom half. When this happens, an X is put on the scoreboard for the home team's score in the ninth inning. In the case of a tie, additional innings are played until one team comes out ahead at the end of an inning. If the home team takes the lead anytime during the bottom of the ninth or of any inning after that, play stops and the home team is declared the winner. This is known as a walk-off.
#
# The basic contest is always between the pitcher for the fielding team and a batter. The pitcher throws—pitches—the ball towards home plate, where the catcher for the fielding team waits (in a crouched stance) to receive it. Behind the catcher stands the home plate umpire. The batter stands in one of the batter's boxes and tries to hit the ball with a bat. The pitcher must keep one foot in contact with the top or front of the pitcher's rubber—a 24×6 in (61×15 cm) plate located atop the pitcher's mound—during the entire pitch, so he can take only one step backward and one forward in delivering the ball. The catcher's job is to receive any pitches that the batter does not hit and to "call" the game by a series of hand movements that signal to the pitcher what pitch to throw and where. The catcher also usually signals the desired location of the ball within the strike zone and "sets up" behind the plate or holds his glove up in the desired location as a target. The catcher's role becomes more crucial depending on how the game is going, and how the pitcher responds to a given situation. Each pitch begins a new play, which might consist of nothing more than the pitch itself.
#
# Each half-inning, the goal of the defending team is to get three members of the other team out. A player who is out must leave the field and wait for his next turn at bat. There are many ways to get batters and baserunners out; some of the most common are catching a batted ball in the air, tag outs, force outs, and strikeouts. After the fielding team has put out three players from the opposing team, that half of the inning is over and the team in the field and the team at bat switch places; there is no upper limit to the number that may bat in rotation before three outs are recorded. Going through the entire order in an inning is referred to as "batting around" and it is indicative of a high-scoring inning. A complete inning consists of each opposing side having a turn (three outs) on offense.
#
# The goal of the team at bat is to score more runs than the opposition; a player may do so by batting, then becoming a baserunner, touching all the bases in order (via one or more plays), and finally touching home plate. A player may also become a baserunner by being inserted as a pinch-runner. To that end, the goal of each batter is to enable baserunners to score or to become a baserunner himself. The batter attempts to hit the ball into fair territory—between the baselines—in such a way that the defending players cannot get them or the baserunners out. In general, the pitcher attempts to prevent this by pitching the ball in such a way that the batter cannot hit it cleanly or, ideally, at all.
#
# A baserunner who has successfully touched home plate without being retired (called out) after touching all previous bases scores a run. In an enclosed field, a fair ball hit over the fence on the fly is an automatic home run, which entitles the batter and all runners to touch all the bases and score. On a field with foul poles, a ball that hits a pole is also a home run. A home run hit with all bases occupied ('bases loaded') is called a grand slam.
#
# ### Answer
# Baseball is a game contested between two teams of 9 players. The defense plays the field and has the ball, and the offense can score by batting the ball and making their way around the bases. The field consists of two parts, the infield, which contains the bases, and the outfield. The bases are 90 feet apart, arranged in diamond format, and advanced counterclockwise. The pitcher's mound is in the center of the infield and is 60 feet 6 inches away from home plate (where the batter stands to try and bat the ball). At the youth level, the bases may be placed as close as 60 feet apart, and the mound may be as close as 46 feet away. The infield contains 6 of the 9 defenders, the pitcher being on the pitcher's mound, the catcher positioned behind home plate to receive the ball from the pitcher, and 4 infielders. The 1st baseman and 2nd baseman are positioned on the right side of the infield near their respective bases. The shortstop and third baseman are positioned on the left side of the infield with the shortstop shaded closer to 2nd base, in a mirrored position from the 2nd baseman. The third baseman is positioned by third base. The outfielders are the 3 remaining defensive players positioned in the large grass outfield in a left, center, and right arrangement. The pitcher must deliver the ball over the plate at the height range of the player's knees to their torso. 3 pitches at this level or swings and misses count as an out. Balls batted that don't land in play, which the lines of play extend from the point of the home plate which is a 90-degree angle count as a strike as long it strikes one or two, a batter cannot foul out for the third strike. If a pitched ball is not called a strike it is a ball, and 4 balls in an at-bat award the batter first base via what is called a walk. Other ways to make outs are if a ball is batted and the fielders catch it before it hits the ground; if the ball hits the ground the runner can be declared out of the fielders touch the base of the advancing runner with possession of the ball prior to the runners' arrival, so long as the runner is forced to advance to the base. If there is no force, the runner must be tagged out. In the event of a fly-out, any runner must re-establish possession of the bag they started at and are not allowed to advance to the next base until the fielder catches the ball. If they don't re-establish possession of their originating base they can be called out if the ball and the fielder possessing it reaches the originating base before they do. 3 outs constitute a half-inning; after each half-inning, the teams rotate from offense to defense. After each team gets 3 outs the full inning is concluded. A game is complete after 9 innings, although youth games are usually 6 or 7 innings. If the teams are tied at the end of regulation, the teams will continuously add extra innings until the tie is broken. A ball that is batted over the outfield fence is considered a homerun and the batter and all base runners can advance safely to home. If a battled ball lands in fair territory and leaves the field of play, it is considered a ground-rule double, and all runners are awarded two bases from where they started. You can substitute players from your bench into the game at any time but players are not allowed to re-enter the game once substituted, so substitutions are done sparingly and strategically. Many leagues employ the designated hitter rule, which allows for a 10th player to bat in place of the pitcher. Balls, strikes, and outs are called by umpires, of which there can be anywhere between 2 and 4.</s>
# Total number of samples: 1581

# %%
lm_dataset.save_to_disk(f"/project/data")

# %%
# !python im-a-llama.py
# Out:
# Logging into the Hugging Face Hub with token hf_oaWwQlP...
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# Downloading (…)lve/main/config.json: 100%|█████| 610/610 [00:00<00:00, 8.00MB/s]
# Downloading (…)fetensors.index.json: 100%|██| 33.4k/33.4k [00:00<00:00, 249MB/s]
# Downloading shards:   0%|                                 | 0/3 [00:00<?, ?it/s]
# Downloading (…)of-00003.safetensors:   0%|          | 0.00/9.95G [00:00<?, ?B/s]
# Downloading (…)of-00003.safetensors:   0%|  | 31.5M/9.95G [00:00<00:36, 275MB/s]
# Downloading (…)of-00003.safetensors:   1%|  | 73.4M/9.95G [00:00<00:29, 335MB/s]
# Downloading (…)of-00003.safetensors:   1%|   | 115M/9.95G [00:00<00:27, 354MB/s]
# Downloading (…)of-00003.safetensors:   2%|   | 157M/9.95G [00:00<00:27, 353MB/s]
# Downloading (…)of-00003.safetensors:   2%|   | 199M/9.95G [00:00<00:27, 356MB/s]
# Downloading (…)of-00003.safetensors:   2%|   | 241M/9.95G [00:00<00:27, 356MB/s]
# Downloading (…)of-00003.safetensors:   3%|   | 283M/9.95G [00:00<00:27, 351MB/s]
# Downloading (…)of-00003.safetensors:   3%|   | 325M/9.95G [00:00<00:27, 351MB/s]
# Downloading (…)of-00003.safetensors:   4%|   | 367M/9.95G [00:01<00:27, 343MB/s]
# Downloading (…)of-00003.safetensors:   4%|   | 409M/9.95G [00:01<00:27, 344MB/s]
# Downloading (…)of-00003.safetensors:   5%|▏  | 451M/9.95G [00:01<00:27, 348MB/s]
# Downloading (…)of-00003.safetensors:   5%|▏  | 493M/9.95G [00:01<00:26, 352MB/s]
# Downloading (…)of-00003.safetensors:   5%|▏  | 535M/9.95G [00:01<00:26, 354MB/s]
# Downloading (…)of-00003.safetensors:   6%|▏  | 577M/9.95G [00:01<00:25, 361MB/s]
# Downloading (…)of-00003.safetensors:   6%|▏  | 619M/9.95G [00:01<00:26, 357MB/s]
# Downloading (…)of-00003.safetensors:   7%|▏  | 661M/9.95G [00:01<00:26, 356MB/s]
# Downloading (…)of-00003.safetensors:   7%|▏  | 703M/9.95G [00:01<00:25, 363MB/s]
# Downloading (…)of-00003.safetensors:   7%|▏  | 744M/9.95G [00:02<00:25, 360MB/s]
# Downloading (…)of-00003.safetensors:   8%|▏  | 786M/9.95G [00:02<00:25, 366MB/s]
# Downloading (…)of-00003.safetensors:   8%|▏  | 828M/9.95G [00:02<00:25, 358MB/s]
# Downloading (…)of-00003.safetensors:   9%|▎  | 870M/9.95G [00:02<00:24, 366MB/s]
# Downloading (…)of-00003.safetensors:   9%|▎  | 912M/9.95G [00:02<00:24, 362MB/s]
# Downloading (…)of-00003.safetensors:  10%|▎  | 954M/9.95G [00:02<00:24, 368MB/s]
# Downloading (…)of-00003.safetensors:  10%|▎  | 996M/9.95G [00:02<00:24, 366MB/s]
# Downloading (…)of-00003.safetensors:  10%|▏ | 1.04G/9.95G [00:02<00:24, 370MB/s]
# Downloading (…)of-00003.safetensors:  11%|▏ | 1.08G/9.95G [00:03<00:24, 368MB/s]
# Downloading (…)of-00003.safetensors:  11%|▏ | 1.12G/9.95G [00:03<00:24, 368MB/s]
# Downloading (…)of-00003.safetensors:  12%|▏ | 1.16G/9.95G [00:03<00:24, 365MB/s]
# Downloading (…)of-00003.safetensors:  12%|▏ | 1.21G/9.95G [00:03<00:24, 362MB/s]
# Downloading (…)of-00003.safetensors:  13%|▎ | 1.25G/9.95G [00:03<00:24, 361MB/s]
# Downloading (…)of-00003.safetensors:  13%|▎ | 1.29G/9.95G [00:03<00:24, 358MB/s]
# Downloading (…)of-00003.safetensors:  13%|▎ | 1.33G/9.95G [00:03<00:24, 356MB/s]
# Downloading (…)of-00003.safetensors:  14%|▎ | 1.37G/9.95G [00:03<00:23, 359MB/s]
# Downloading (…)of-00003.safetensors:  14%|▎ | 1.42G/9.95G [00:03<00:24, 354MB/s]
# Downloading (…)of-00003.safetensors:  15%|▎ | 1.46G/9.95G [00:04<00:23, 361MB/s]
# Downloading (…)of-00003.safetensors:  15%|▎ | 1.50G/9.95G [00:04<00:23, 359MB/s]
# Downloading (…)of-00003.safetensors:  15%|▎ | 1.54G/9.95G [00:04<00:23, 354MB/s]
# Downloading (…)of-00003.safetensors:  16%|▎ | 1.58G/9.95G [00:04<00:23, 353MB/s]
# Downloading (…)of-00003.safetensors:  16%|▎ | 1.63G/9.95G [00:04<00:23, 354MB/s]
# Downloading (…)of-00003.safetensors:  17%|▎ | 1.67G/9.95G [00:04<00:23, 354MB/s]
# Downloading (…)of-00003.safetensors:  17%|▎ | 1.71G/9.95G [00:04<00:23, 352MB/s]
# Downloading (…)of-00003.safetensors:  18%|▎ | 1.75G/9.95G [00:04<00:22, 357MB/s]
# Downloading (…)of-00003.safetensors:  18%|▎ | 1.79G/9.95G [00:05<00:22, 356MB/s]
# Downloading (…)of-00003.safetensors:  18%|▎ | 1.84G/9.95G [00:05<00:22, 354MB/s]
# Downloading (…)of-00003.safetensors:  19%|▍ | 1.88G/9.95G [00:05<00:22, 359MB/s]
# Downloading (…)of-00003.safetensors:  19%|▍ | 1.92G/9.95G [00:05<00:22, 360MB/s]
# Downloading (…)of-00003.safetensors:  20%|▍ | 1.96G/9.95G [00:05<00:22, 358MB/s]
# Downloading (…)of-00003.safetensors:  20%|▍ | 2.00G/9.95G [00:05<00:22, 355MB/s]
# Downloading (…)of-00003.safetensors:  21%|▍ | 2.04G/9.95G [00:05<00:22, 353MB/s]
# Downloading (…)of-00003.safetensors:  21%|▍ | 2.09G/9.95G [00:05<00:22, 356MB/s]
# Downloading (…)of-00003.safetensors:  21%|▍ | 2.13G/9.95G [00:05<00:21, 357MB/s]
# Downloading (…)of-00003.safetensors:  22%|▍ | 2.17G/9.95G [00:06<00:21, 359MB/s]
# Downloading (…)of-00003.safetensors:  22%|▍ | 2.21G/9.95G [00:06<00:21, 355MB/s]
# Downloading (…)of-00003.safetensors:  23%|▍ | 2.25G/9.95G [00:06<00:21, 356MB/s]
# Downloading (…)of-00003.safetensors:  23%|▍ | 2.30G/9.95G [00:06<00:21, 360MB/s]
# Downloading (…)of-00003.safetensors:  24%|▍ | 2.34G/9.95G [00:06<00:21, 360MB/s]
# Downloading (…)of-00003.safetensors:  24%|▍ | 2.38G/9.95G [00:06<00:21, 357MB/s]
# Downloading (…)of-00003.safetensors:  24%|▍ | 2.42G/9.95G [00:06<00:21, 356MB/s]
# Downloading (…)of-00003.safetensors:  25%|▍ | 2.46G/9.95G [00:06<00:20, 357MB/s]
# Downloading (…)of-00003.safetensors:  25%|▌ | 2.51G/9.95G [00:07<00:20, 363MB/s]
# Downloading (…)of-00003.safetensors:  26%|▌ | 2.55G/9.95G [00:07<00:20, 361MB/s]
# Downloading (…)of-00003.safetensors:  26%|▌ | 2.59G/9.95G [00:07<00:20, 358MB/s]
# Downloading (…)of-00003.safetensors:  26%|▌ | 2.63G/9.95G [00:07<00:20, 355MB/s]
# Downloading (…)of-00003.safetensors:  27%|▌ | 2.67G/9.95G [00:07<00:20, 355MB/s]
# Downloading (…)of-00003.safetensors:  27%|▌ | 2.72G/9.95G [00:07<00:20, 355MB/s]
# Downloading (…)of-00003.safetensors:  28%|▌ | 2.76G/9.95G [00:07<00:20, 352MB/s]
# Downloading (…)of-00003.safetensors:  28%|▌ | 2.80G/9.95G [00:07<00:20, 357MB/s]
# Downloading (…)of-00003.safetensors:  29%|▌ | 2.84G/9.95G [00:07<00:20, 355MB/s]
# Downloading (…)of-00003.safetensors:  29%|▌ | 2.88G/9.95G [00:08<00:19, 355MB/s]
# Downloading (…)of-00003.safetensors:  29%|▌ | 2.93G/9.95G [00:08<00:19, 357MB/s]
# Downloading (…)of-00003.safetensors:  30%|▌ | 2.97G/9.95G [00:08<00:19, 356MB/s]
# Downloading (…)of-00003.safetensors:  30%|▌ | 3.01G/9.95G [00:08<00:19, 356MB/s]
# Downloading (…)of-00003.safetensors:  31%|▌ | 3.05G/9.95G [00:08<00:19, 356MB/s]
# Downloading (…)of-00003.safetensors:  31%|▌ | 3.09G/9.95G [00:08<00:19, 355MB/s]
# Downloading (…)of-00003.safetensors:  32%|▋ | 3.14G/9.95G [00:08<00:19, 357MB/s]
# Downloading (…)of-00003.safetensors:  32%|▋ | 3.18G/9.95G [00:08<00:19, 349MB/s]
# Downloading (…)of-00003.safetensors:  32%|▋ | 3.22G/9.95G [00:09<00:18, 355MB/s]
# Downloading (…)of-00003.safetensors:  33%|▋ | 3.26G/9.95G [00:09<00:18, 359MB/s]
# Downloading (…)of-00003.safetensors:  33%|▋ | 3.30G/9.95G [00:09<00:18, 358MB/s]
# Downloading (…)of-00003.safetensors:  34%|▋ | 3.34G/9.95G [00:09<00:18, 353MB/s]
# Downloading (…)of-00003.safetensors:  34%|▋ | 3.39G/9.95G [00:09<00:18, 356MB/s]
# Downloading (…)of-00003.safetensors:  34%|▋ | 3.43G/9.95G [00:09<00:18, 359MB/s]
# Downloading (…)of-00003.safetensors:  35%|▋ | 3.47G/9.95G [00:09<00:17, 361MB/s]
# Downloading (…)of-00003.safetensors:  35%|▋ | 3.51G/9.95G [00:09<00:17, 358MB/s]
# Downloading (…)of-00003.safetensors:  36%|▋ | 3.55G/9.95G [00:09<00:17, 357MB/s]
# Downloading (…)of-00003.safetensors:  36%|▋ | 3.60G/9.95G [00:10<00:17, 359MB/s]
# Downloading (…)of-00003.safetensors:  37%|▋ | 3.64G/9.95G [00:10<00:17, 362MB/s]
# Downloading (…)of-00003.safetensors:  37%|▋ | 3.68G/9.95G [00:10<00:17, 358MB/s]
# Downloading (…)of-00003.safetensors:  37%|▋ | 3.72G/9.95G [00:10<00:17, 360MB/s]
# Downloading (…)of-00003.safetensors:  38%|▊ | 3.76G/9.95G [00:10<00:25, 243MB/s]
# Downloading (…)of-00003.safetensors:  38%|▊ | 3.81G/9.95G [00:10<00:22, 270MB/s]
# Downloading (…)of-00003.safetensors:  39%|▊ | 3.85G/9.95G [00:10<00:20, 294MB/s]
# Downloading (…)of-00003.safetensors:  39%|▊ | 3.89G/9.95G [00:11<00:19, 308MB/s]
# Downloading (…)of-00003.safetensors:  40%|▊ | 3.93G/9.95G [00:11<00:18, 322MB/s]
# Downloading (…)of-00003.safetensors:  40%|▊ | 3.97G/9.95G [00:11<00:17, 333MB/s]
# Downloading (…)of-00003.safetensors:  40%|▊ | 4.02G/9.95G [00:11<00:17, 337MB/s]
# Downloading (…)of-00003.safetensors:  41%|▊ | 4.06G/9.95G [00:11<00:17, 340MB/s]
# Downloading (…)of-00003.safetensors:  41%|▊ | 4.10G/9.95G [00:11<00:16, 344MB/s]
# Downloading (…)of-00003.safetensors:  42%|▊ | 4.14G/9.95G [00:11<00:17, 332MB/s]
# Downloading (…)of-00003.safetensors:  42%|▊ | 4.18G/9.95G [00:11<00:16, 345MB/s]
# Downloading (…)of-00003.safetensors:  42%|▊ | 4.23G/9.95G [00:12<00:16, 353MB/s]
# Downloading (…)of-00003.safetensors:  43%|▊ | 4.27G/9.95G [00:12<00:15, 359MB/s]
# Downloading (…)of-00003.safetensors:  43%|▊ | 4.31G/9.95G [00:12<00:15, 361MB/s]
# Downloading (…)of-00003.safetensors:  44%|▊ | 4.35G/9.95G [00:12<00:15, 365MB/s]
# Downloading (…)of-00003.safetensors:  44%|▉ | 4.39G/9.95G [00:12<00:15, 367MB/s]
# Downloading (…)of-00003.safetensors:  45%|▉ | 4.44G/9.95G [00:12<00:14, 368MB/s]
# Downloading (…)of-00003.safetensors:  45%|▉ | 4.48G/9.95G [00:12<00:14, 369MB/s]
# Downloading (…)of-00003.safetensors:  45%|▉ | 4.52G/9.95G [00:12<00:14, 369MB/s]
# Downloading (…)of-00003.safetensors:  46%|▉ | 4.56G/9.95G [00:12<00:14, 366MB/s]
# Downloading (…)of-00003.safetensors:  46%|▉ | 4.60G/9.95G [00:13<00:14, 360MB/s]
# Downloading (…)of-00003.safetensors:  47%|▉ | 4.65G/9.95G [00:13<00:14, 355MB/s]
# Downloading (…)of-00003.safetensors:  47%|▉ | 4.69G/9.95G [00:13<00:14, 360MB/s]
# Downloading (…)of-00003.safetensors:  48%|▉ | 4.73G/9.95G [00:13<00:14, 362MB/s]
# Downloading (…)of-00003.safetensors:  48%|▉ | 4.77G/9.95G [00:13<00:14, 367MB/s]
# Downloading (…)of-00003.safetensors:  48%|▉ | 4.81G/9.95G [00:13<00:13, 369MB/s]
# Downloading (…)of-00003.safetensors:  49%|▉ | 4.85G/9.95G [00:13<00:14, 353MB/s]
# Downloading (…)of-00003.safetensors:  49%|▉ | 4.90G/9.95G [00:13<00:14, 352MB/s]
# Downloading (…)of-00003.safetensors:  50%|▉ | 4.94G/9.95G [00:13<00:13, 360MB/s]
# Downloading (…)of-00003.safetensors:  50%|█ | 4.98G/9.95G [00:14<00:13, 363MB/s]
# Downloading (…)of-00003.safetensors:  50%|█ | 5.02G/9.95G [00:14<00:13, 368MB/s]
# Downloading (…)of-00003.safetensors:  51%|█ | 5.06G/9.95G [00:14<00:13, 370MB/s]
# Downloading (…)of-00003.safetensors:  51%|█ | 5.11G/9.95G [00:14<00:12, 375MB/s]
# Downloading (…)of-00003.safetensors:  52%|█ | 5.15G/9.95G [00:14<00:12, 377MB/s]
# Downloading (…)of-00003.safetensors:  52%|█ | 5.19G/9.95G [00:14<00:12, 375MB/s]
# Downloading (…)of-00003.safetensors:  53%|█ | 5.23G/9.95G [00:14<00:12, 376MB/s]
# Downloading (…)of-00003.safetensors:  53%|█ | 5.27G/9.95G [00:14<00:12, 375MB/s]
# Downloading (…)of-00003.safetensors:  53%|█ | 5.32G/9.95G [00:14<00:12, 378MB/s]
# Downloading (…)of-00003.safetensors:  54%|█ | 5.36G/9.95G [00:15<00:12, 378MB/s]
# Downloading (…)of-00003.safetensors:  54%|█ | 5.40G/9.95G [00:15<00:12, 374MB/s]
# Downloading (…)of-00003.safetensors:  55%|█ | 5.44G/9.95G [00:15<00:11, 376MB/s]
# Downloading (…)of-00003.safetensors:  55%|█ | 5.48G/9.95G [00:15<00:11, 377MB/s]
# Downloading (…)of-00003.safetensors:  56%|█ | 5.53G/9.95G [00:15<00:11, 376MB/s]
# Downloading (…)of-00003.safetensors:  56%|█ | 5.57G/9.95G [00:15<00:11, 379MB/s]
# Downloading (…)of-00003.safetensors:  56%|█▏| 5.61G/9.95G [00:15<00:11, 378MB/s]
# Downloading (…)of-00003.safetensors:  57%|█▏| 5.65G/9.95G [00:15<00:11, 378MB/s]
# Downloading (…)of-00003.safetensors:  57%|█▏| 5.69G/9.95G [00:15<00:11, 376MB/s]
# Downloading (…)of-00003.safetensors:  58%|█▏| 5.74G/9.95G [00:16<00:11, 375MB/s]
# Downloading (…)of-00003.safetensors:  58%|█▏| 5.78G/9.95G [00:16<00:11, 374MB/s]
# Downloading (…)of-00003.safetensors:  58%|█▏| 5.82G/9.95G [00:16<00:14, 295MB/s]
# Downloading (…)of-00003.safetensors:  59%|█▏| 5.86G/9.95G [00:16<00:12, 316MB/s]
# Downloading (…)of-00003.safetensors:  59%|█▏| 5.90G/9.95G [00:16<00:12, 333MB/s]
# Downloading (…)of-00003.safetensors:  60%|█▏| 5.95G/9.95G [00:16<00:11, 341MB/s]
# Downloading (…)of-00003.safetensors:  60%|█▏| 5.99G/9.95G [00:16<00:11, 334MB/s]
# Downloading (…)of-00003.safetensors:  61%|█▏| 6.03G/9.95G [00:17<00:11, 345MB/s]
# Downloading (…)of-00003.safetensors:  61%|█▏| 6.07G/9.95G [00:17<00:10, 353MB/s]
# Downloading (…)of-00003.safetensors:  61%|█▏| 6.11G/9.95G [00:17<00:10, 357MB/s]
# Downloading (…)of-00003.safetensors:  62%|█▏| 6.16G/9.95G [00:17<00:10, 364MB/s]
# Downloading (…)of-00003.safetensors:  62%|█▏| 6.20G/9.95G [00:17<00:10, 366MB/s]
# Downloading (…)of-00003.safetensors:  63%|█▎| 6.24G/9.95G [00:17<00:10, 370MB/s]
# Downloading (…)of-00003.safetensors:  63%|█▎| 6.28G/9.95G [00:17<00:10, 358MB/s]
# Downloading (…)of-00003.safetensors:  64%|█▎| 6.32G/9.95G [00:17<00:09, 366MB/s]
# Downloading (…)of-00003.safetensors:  64%|█▎| 6.36G/9.95G [00:17<00:09, 371MB/s]
# Downloading (…)of-00003.safetensors:  64%|█▎| 6.41G/9.95G [00:18<00:09, 373MB/s]
# Downloading (…)of-00003.safetensors:  65%|█▎| 6.45G/9.95G [00:18<00:09, 376MB/s]
# Downloading (…)of-00003.safetensors:  65%|█▎| 6.49G/9.95G [00:18<00:09, 377MB/s]
# Downloading (…)of-00003.safetensors:  66%|█▎| 6.53G/9.95G [00:18<00:09, 378MB/s]
# Downloading (…)of-00003.safetensors:  66%|█▎| 6.57G/9.95G [00:18<00:10, 330MB/s]
# Downloading (…)of-00003.safetensors:  67%|█▎| 6.62G/9.95G [00:18<00:10, 325MB/s]
# Downloading (…)of-00003.safetensors:  67%|█▎| 6.66G/9.95G [00:18<00:10, 315MB/s]
# Downloading (…)of-00003.safetensors:  67%|█▎| 6.70G/9.95G [00:18<00:10, 318MB/s]
# Downloading (…)of-00003.safetensors:  68%|█▎| 6.74G/9.95G [00:19<00:09, 333MB/s]
# Downloading (…)of-00003.safetensors:  68%|█▎| 6.78G/9.95G [00:19<00:09, 330MB/s]
# Downloading (…)of-00003.safetensors:  69%|█▎| 6.83G/9.95G [00:19<00:09, 341MB/s]
# Downloading (…)of-00003.safetensors:  69%|█▍| 6.87G/9.95G [00:19<00:08, 352MB/s]
# Downloading (…)of-00003.safetensors:  69%|█▍| 6.91G/9.95G [00:19<00:08, 360MB/s]
# Downloading (…)of-00003.safetensors:  70%|█▍| 6.95G/9.95G [00:19<00:08, 364MB/s]
# Downloading (…)of-00003.safetensors:  70%|█▍| 6.99G/9.95G [00:19<00:08, 369MB/s]
# Downloading (…)of-00003.safetensors:  71%|█▍| 7.04G/9.95G [00:19<00:07, 371MB/s]
# Downloading (…)of-00003.safetensors:  71%|█▍| 7.08G/9.95G [00:19<00:07, 372MB/s]
# Downloading (…)of-00003.safetensors:  72%|█▍| 7.12G/9.95G [00:20<00:07, 376MB/s]
# Downloading (…)of-00003.safetensors:  72%|█▍| 7.16G/9.95G [00:20<00:07, 375MB/s]
# Downloading (…)of-00003.safetensors:  72%|█▍| 7.20G/9.95G [00:20<00:07, 375MB/s]
# Downloading (…)of-00003.safetensors:  73%|█▍| 7.25G/9.95G [00:20<00:08, 317MB/s]
# Downloading (…)of-00003.safetensors:  73%|█▍| 7.29G/9.95G [00:20<00:08, 326MB/s]
# Downloading (…)of-00003.safetensors:  74%|█▍| 7.33G/9.95G [00:20<00:07, 342MB/s]
# Downloading (…)of-00003.safetensors:  74%|█▍| 7.37G/9.95G [00:20<00:07, 352MB/s]
# Downloading (…)of-00003.safetensors:  75%|█▍| 7.41G/9.95G [00:20<00:07, 358MB/s]
# Downloading (…)of-00003.safetensors:  75%|█▍| 7.46G/9.95G [00:21<00:06, 365MB/s]
# Downloading (…)of-00003.safetensors:  75%|█▌| 7.50G/9.95G [00:21<00:07, 342MB/s]
# Downloading (…)of-00003.safetensors:  76%|█▌| 7.54G/9.95G [00:21<00:06, 350MB/s]
# Downloading (…)of-00003.safetensors:  76%|█▌| 7.58G/9.95G [00:21<00:06, 357MB/s]
# Downloading (…)of-00003.safetensors:  77%|█▌| 7.62G/9.95G [00:21<00:06, 362MB/s]
# Downloading (…)of-00003.safetensors:  77%|█▌| 7.67G/9.95G [00:21<00:07, 316MB/s]
# Downloading (…)of-00003.safetensors:  77%|█▌| 7.71G/9.95G [00:21<00:08, 273MB/s]
# Downloading (…)of-00003.safetensors:  78%|█▌| 7.74G/9.95G [00:21<00:07, 278MB/s]
# Downloading (…)of-00003.safetensors:  78%|█▌| 7.78G/9.95G [00:22<00:07, 296MB/s]
# Downloading (…)of-00003.safetensors:  79%|█▌| 7.82G/9.95G [00:22<00:06, 318MB/s]
# Downloading (…)of-00003.safetensors:  79%|█▌| 7.86G/9.95G [00:22<00:06, 335MB/s]
# Downloading (…)of-00003.safetensors:  79%|█▌| 7.91G/9.95G [00:22<00:05, 348MB/s]
# Downloading (…)of-00003.safetensors:  80%|█▌| 7.95G/9.95G [00:22<00:05, 356MB/s]
# Downloading (…)of-00003.safetensors:  80%|█▌| 7.99G/9.95G [00:22<00:05, 364MB/s]
# Downloading (…)of-00003.safetensors:  81%|█▌| 8.03G/9.95G [00:22<00:05, 354MB/s]
# Downloading (…)of-00003.safetensors:  81%|█▌| 8.07G/9.95G [00:22<00:05, 349MB/s]
# Downloading (…)of-00003.safetensors:  82%|█▋| 8.12G/9.95G [00:23<00:05, 358MB/s]
# Downloading (…)of-00003.safetensors:  82%|█▋| 8.16G/9.95G [00:23<00:04, 362MB/s]
# Downloading (…)of-00003.safetensors:  82%|█▋| 8.20G/9.95G [00:23<00:04, 361MB/s]
# Downloading (…)of-00003.safetensors:  83%|█▋| 8.24G/9.95G [00:23<00:04, 360MB/s]
# Downloading (…)of-00003.safetensors:  83%|█▋| 8.28G/9.95G [00:23<00:04, 352MB/s]
# Downloading (…)of-00003.safetensors:  84%|█▋| 8.33G/9.95G [00:23<00:04, 358MB/s]
# Downloading (…)of-00003.safetensors:  84%|█▋| 8.37G/9.95G [00:23<00:04, 362MB/s]
# Downloading (…)of-00003.safetensors:  85%|█▋| 8.41G/9.95G [00:23<00:04, 361MB/s]
# Downloading (…)of-00003.safetensors:  85%|█▋| 8.45G/9.95G [00:23<00:04, 362MB/s]
# Downloading (…)of-00003.safetensors:  85%|█▋| 8.49G/9.95G [00:24<00:03, 365MB/s]
# Downloading (…)of-00003.safetensors:  86%|█▋| 8.54G/9.95G [00:24<00:03, 370MB/s]
# Downloading (…)of-00003.safetensors:  86%|█▋| 8.58G/9.95G [00:24<00:03, 374MB/s]
# Downloading (…)of-00003.safetensors:  87%|█▋| 8.62G/9.95G [00:24<00:03, 373MB/s]
# Downloading (…)of-00003.safetensors:  87%|█▋| 8.66G/9.95G [00:24<00:03, 372MB/s]
# Downloading (…)of-00003.safetensors:  87%|█▋| 8.70G/9.95G [00:24<00:03, 374MB/s]
# Downloading (…)of-00003.safetensors:  88%|█▊| 8.75G/9.95G [00:24<00:03, 377MB/s]
# Downloading (…)of-00003.safetensors:  88%|█▊| 8.79G/9.95G [00:24<00:03, 367MB/s]
# Downloading (…)of-00003.safetensors:  89%|█▊| 8.83G/9.95G [00:24<00:03, 372MB/s]
# Downloading (…)of-00003.safetensors:  89%|█▊| 8.87G/9.95G [00:25<00:02, 373MB/s]
# Downloading (…)of-00003.safetensors:  90%|█▊| 8.91G/9.95G [00:25<00:02, 373MB/s]
# Downloading (…)of-00003.safetensors:  90%|█▊| 8.95G/9.95G [00:25<00:03, 327MB/s]
# Downloading (…)of-00003.safetensors:  90%|█▊| 9.00G/9.95G [00:25<00:02, 337MB/s]
# Downloading (…)of-00003.safetensors:  91%|█▊| 9.04G/9.95G [00:25<00:02, 349MB/s]
# Downloading (…)of-00003.safetensors:  91%|█▊| 9.08G/9.95G [00:25<00:02, 358MB/s]
# Downloading (…)of-00003.safetensors:  92%|█▊| 9.12G/9.95G [00:25<00:02, 362MB/s]
# Downloading (…)of-00003.safetensors:  92%|█▊| 9.16G/9.95G [00:25<00:02, 369MB/s]
# Downloading (…)of-00003.safetensors:  93%|█▊| 9.21G/9.95G [00:26<00:01, 373MB/s]
# Downloading (…)of-00003.safetensors:  93%|█▊| 9.25G/9.95G [00:26<00:01, 353MB/s]
# Downloading (…)of-00003.safetensors:  93%|█▊| 9.29G/9.95G [00:26<00:01, 361MB/s]
# Downloading (…)of-00003.safetensors:  94%|█▉| 9.33G/9.95G [00:26<00:01, 357MB/s]
# Downloading (…)of-00003.safetensors:  94%|█▉| 9.37G/9.95G [00:26<00:01, 361MB/s]
# Downloading (…)of-00003.safetensors:  95%|█▉| 9.42G/9.95G [00:26<00:01, 359MB/s]
# Downloading (…)of-00003.safetensors:  95%|█▉| 9.46G/9.95G [00:26<00:01, 359MB/s]
# Downloading (…)of-00003.safetensors:  95%|█▉| 9.50G/9.95G [00:26<00:01, 347MB/s]
# Downloading (…)of-00003.safetensors:  96%|█▉| 9.54G/9.95G [00:26<00:01, 357MB/s]
# Downloading (…)of-00003.safetensors:  96%|█▉| 9.58G/9.95G [00:27<00:01, 362MB/s]
# Downloading (…)of-00003.safetensors:  97%|█▉| 9.63G/9.95G [00:27<00:00, 367MB/s]
# Downloading (…)of-00003.safetensors:  97%|█▉| 9.67G/9.95G [00:27<00:00, 370MB/s]
# Downloading (…)of-00003.safetensors:  98%|█▉| 9.71G/9.95G [00:27<00:00, 374MB/s]
# Downloading (…)of-00003.safetensors:  98%|█▉| 9.75G/9.95G [00:27<00:00, 376MB/s]
# Downloading (…)of-00003.safetensors:  98%|█▉| 9.79G/9.95G [00:27<00:00, 373MB/s]
# Downloading (…)of-00003.safetensors:  99%|█▉| 9.84G/9.95G [00:27<00:00, 356MB/s]
# Downloading (…)of-00003.safetensors:  99%|█▉| 9.88G/9.95G [00:27<00:00, 323MB/s]
# Downloading (…)of-00003.safetensors: 100%|██| 9.95G/9.95G [00:28<00:00, 353MB/s]
# Downloading shards:  33%|████████▎                | 1/3 [00:28<00:56, 28.22s/it]
# Downloading (…)of-00003.safetensors:   0%|          | 0.00/9.90G [00:00<?, ?B/s]
# Downloading (…)of-00003.safetensors:   0%|  | 41.9M/9.90G [00:00<00:28, 342MB/s]
# Downloading (…)of-00003.safetensors:   1%|  | 83.9M/9.90G [00:00<00:27, 357MB/s]
# Downloading (…)of-00003.safetensors:   1%|   | 126M/9.90G [00:00<00:27, 360MB/s]
# Downloading (…)of-00003.safetensors:   2%|   | 168M/9.90G [00:00<00:26, 368MB/s]
# Downloading (…)of-00003.safetensors:   2%|   | 210M/9.90G [00:00<00:25, 375MB/s]
# Downloading (…)of-00003.safetensors:   3%|   | 252M/9.90G [00:00<00:25, 376MB/s]
# Downloading (…)of-00003.safetensors:   3%|   | 294M/9.90G [00:00<00:25, 377MB/s]
# Downloading (…)of-00003.safetensors:   3%|   | 336M/9.90G [00:00<00:26, 356MB/s]
# Downloading (…)of-00003.safetensors:   4%|   | 377M/9.90G [00:01<00:26, 362MB/s]
# Downloading (…)of-00003.safetensors:   4%|▏  | 419M/9.90G [00:01<00:25, 367MB/s]
# Downloading (…)of-00003.safetensors:   5%|▏  | 461M/9.90G [00:01<00:25, 370MB/s]
# Downloading (…)of-00003.safetensors:   5%|▏  | 503M/9.90G [00:01<00:25, 374MB/s]
# Downloading (…)of-00003.safetensors:   6%|▏  | 545M/9.90G [00:01<00:24, 375MB/s]
# Downloading (…)of-00003.safetensors:   6%|▏  | 587M/9.90G [00:01<00:24, 374MB/s]
# Downloading (…)of-00003.safetensors:   6%|▏  | 629M/9.90G [00:01<00:24, 377MB/s]
# Downloading (…)of-00003.safetensors:   7%|▏  | 671M/9.90G [00:01<00:24, 374MB/s]
# Downloading (…)of-00003.safetensors:   7%|▏  | 713M/9.90G [00:01<00:24, 377MB/s]
# Downloading (…)of-00003.safetensors:   8%|▏  | 755M/9.90G [00:02<00:24, 377MB/s]
# Downloading (…)of-00003.safetensors:   8%|▏  | 797M/9.90G [00:02<00:24, 368MB/s]
# Downloading (…)of-00003.safetensors:   8%|▎  | 839M/9.90G [00:02<00:24, 370MB/s]
# Downloading (…)of-00003.safetensors:   9%|▎  | 881M/9.90G [00:02<00:24, 375MB/s]
# Downloading (…)of-00003.safetensors:   9%|▎  | 923M/9.90G [00:02<00:23, 378MB/s]
# Downloading (…)of-00003.safetensors:  10%|▎  | 965M/9.90G [00:02<00:23, 376MB/s]
# Downloading (…)of-00003.safetensors:  10%|▏ | 1.01G/9.90G [00:02<00:23, 377MB/s]
# Downloading (…)of-00003.safetensors:  11%|▏ | 1.05G/9.90G [00:02<00:23, 377MB/s]
# Downloading (…)of-00003.safetensors:  11%|▏ | 1.09G/9.90G [00:02<00:23, 375MB/s]
# Downloading (…)of-00003.safetensors:  11%|▏ | 1.13G/9.90G [00:03<00:23, 375MB/s]
# Downloading (…)of-00003.safetensors:  12%|▏ | 1.17G/9.90G [00:03<00:23, 375MB/s]
# Downloading (…)of-00003.safetensors:  12%|▏ | 1.22G/9.90G [00:03<00:26, 331MB/s]
# Downloading (…)of-00003.safetensors:  13%|▎ | 1.26G/9.90G [00:03<00:25, 338MB/s]
# Downloading (…)of-00003.safetensors:  13%|▎ | 1.30G/9.90G [00:03<00:24, 348MB/s]
# Downloading (…)of-00003.safetensors:  14%|▎ | 1.34G/9.90G [00:03<00:24, 350MB/s]
# Downloading (…)of-00003.safetensors:  14%|▎ | 1.38G/9.90G [00:03<00:35, 240MB/s]
# Downloading (…)of-00003.safetensors:  14%|▎ | 1.43G/9.90G [00:04<00:31, 267MB/s]
# Downloading (…)of-00003.safetensors:  15%|▎ | 1.47G/9.90G [00:04<00:28, 293MB/s]
# Downloading (…)of-00003.safetensors:  15%|▎ | 1.51G/9.90G [00:04<00:26, 314MB/s]
# Downloading (…)of-00003.safetensors:  16%|▎ | 1.55G/9.90G [00:04<00:25, 330MB/s]
# Downloading (…)of-00003.safetensors:  16%|▎ | 1.59G/9.90G [00:04<00:24, 338MB/s]
# Downloading (…)of-00003.safetensors:  17%|▎ | 1.64G/9.90G [00:04<00:23, 350MB/s]
# Downloading (…)of-00003.safetensors:  17%|▎ | 1.68G/9.90G [00:04<00:22, 359MB/s]
# Downloading (…)of-00003.safetensors:  17%|▎ | 1.72G/9.90G [00:04<00:22, 360MB/s]
# Downloading (…)of-00003.safetensors:  18%|▎ | 1.76G/9.90G [00:05<00:23, 345MB/s]
# Downloading (…)of-00003.safetensors:  18%|▎ | 1.80G/9.90G [00:05<00:23, 347MB/s]
# Downloading (…)of-00003.safetensors:  19%|▎ | 1.85G/9.90G [00:05<00:22, 355MB/s]
# Downloading (…)of-00003.safetensors:  19%|▍ | 1.89G/9.90G [00:05<00:22, 358MB/s]
# Downloading (…)of-00003.safetensors:  19%|▍ | 1.93G/9.90G [00:05<00:21, 365MB/s]
# Downloading (…)of-00003.safetensors:  20%|▍ | 1.97G/9.90G [00:05<00:21, 370MB/s]
# Downloading (…)of-00003.safetensors:  20%|▍ | 2.01G/9.90G [00:05<00:21, 367MB/s]
# Downloading (…)of-00003.safetensors:  21%|▍ | 2.06G/9.90G [00:05<00:21, 363MB/s]
# Downloading (…)of-00003.safetensors:  21%|▍ | 2.10G/9.90G [00:05<00:21, 368MB/s]
# Downloading (…)of-00003.safetensors:  22%|▍ | 2.14G/9.90G [00:06<00:21, 370MB/s]
# Downloading (…)of-00003.safetensors:  22%|▍ | 2.18G/9.90G [00:06<00:22, 346MB/s]
# Downloading (…)of-00003.safetensors:  22%|▍ | 2.22G/9.90G [00:06<00:21, 353MB/s]
# Downloading (…)of-00003.safetensors:  23%|▍ | 2.26G/9.90G [00:06<00:21, 362MB/s]
# Downloading (…)of-00003.safetensors:  23%|▍ | 2.31G/9.90G [00:06<00:20, 367MB/s]
# Downloading (…)of-00003.safetensors:  24%|▍ | 2.35G/9.90G [00:06<00:20, 368MB/s]
# Downloading (…)of-00003.safetensors:  24%|▍ | 2.39G/9.90G [00:06<00:20, 372MB/s]
# Downloading (…)of-00003.safetensors:  25%|▍ | 2.43G/9.90G [00:06<00:19, 375MB/s]
# Downloading (…)of-00003.safetensors:  25%|▍ | 2.47G/9.90G [00:06<00:19, 376MB/s]
# Downloading (…)of-00003.safetensors:  25%|▌ | 2.52G/9.90G [00:07<00:19, 377MB/s]
# Downloading (…)of-00003.safetensors:  26%|▌ | 2.56G/9.90G [00:07<00:19, 377MB/s]
# Downloading (…)of-00003.safetensors:  26%|▌ | 2.60G/9.90G [00:07<00:19, 376MB/s]
# Downloading (…)of-00003.safetensors:  27%|▌ | 2.64G/9.90G [00:07<00:19, 378MB/s]
# Downloading (…)of-00003.safetensors:  27%|▌ | 2.68G/9.90G [00:07<00:19, 378MB/s]
# Downloading (…)of-00003.safetensors:  28%|▌ | 2.73G/9.90G [00:07<00:20, 344MB/s]
# Downloading (…)of-00003.safetensors:  28%|▌ | 2.77G/9.90G [00:07<00:25, 276MB/s]
# Downloading (…)of-00003.safetensors:  28%|▌ | 2.80G/9.90G [00:08<00:28, 250MB/s]
# Downloading (…)of-00003.safetensors:  29%|▌ | 2.84G/9.90G [00:08<00:25, 281MB/s]
# Downloading (…)of-00003.safetensors:  29%|▌ | 2.88G/9.90G [00:08<00:23, 303MB/s]
# Downloading (…)of-00003.safetensors:  30%|▌ | 2.93G/9.90G [00:08<00:21, 322MB/s]
# Downloading (…)of-00003.safetensors:  30%|▌ | 2.97G/9.90G [00:08<00:20, 338MB/s]
# Downloading (…)of-00003.safetensors:  30%|▌ | 3.01G/9.90G [00:08<00:19, 350MB/s]
# Downloading (…)of-00003.safetensors:  31%|▌ | 3.05G/9.90G [00:08<00:19, 344MB/s]
# Downloading (…)of-00003.safetensors:  31%|▌ | 3.09G/9.90G [00:08<00:19, 352MB/s]
# Downloading (…)of-00003.safetensors:  32%|▋ | 3.14G/9.90G [00:08<00:18, 360MB/s]
# Downloading (…)of-00003.safetensors:  32%|▋ | 3.18G/9.90G [00:09<00:18, 368MB/s]
# Downloading (…)of-00003.safetensors:  33%|▋ | 3.22G/9.90G [00:09<00:17, 373MB/s]
# Downloading (…)of-00003.safetensors:  33%|▋ | 3.26G/9.90G [00:09<00:18, 357MB/s]
# Downloading (…)of-00003.safetensors:  33%|▋ | 3.30G/9.90G [00:09<00:18, 363MB/s]
# Downloading (…)of-00003.safetensors:  34%|▋ | 3.34G/9.90G [00:09<00:17, 368MB/s]
# Downloading (…)of-00003.safetensors:  34%|▋ | 3.39G/9.90G [00:09<00:17, 372MB/s]
# Downloading (…)of-00003.safetensors:  35%|▋ | 3.43G/9.90G [00:09<00:17, 376MB/s]
# Downloading (…)of-00003.safetensors:  35%|▋ | 3.47G/9.90G [00:09<00:17, 374MB/s]
# Downloading (…)of-00003.safetensors:  35%|▋ | 3.51G/9.90G [00:09<00:17, 368MB/s]
# Downloading (…)of-00003.safetensors:  36%|▋ | 3.55G/9.90G [00:10<00:17, 369MB/s]
# Downloading (…)of-00003.safetensors:  36%|▋ | 3.60G/9.90G [00:10<00:17, 358MB/s]
# Downloading (…)of-00003.safetensors:  37%|▋ | 3.64G/9.90G [00:10<00:17, 355MB/s]
# Downloading (…)of-00003.safetensors:  37%|▋ | 3.68G/9.90G [00:10<00:17, 359MB/s]
# Downloading (…)of-00003.safetensors:  38%|▊ | 3.72G/9.90G [00:10<00:17, 363MB/s]
# Downloading (…)of-00003.safetensors:  38%|▊ | 3.76G/9.90G [00:10<00:16, 366MB/s]
# Downloading (…)of-00003.safetensors:  38%|▊ | 3.81G/9.90G [00:10<00:16, 364MB/s]
# Downloading (…)of-00003.safetensors:  39%|▊ | 3.85G/9.90G [00:10<00:16, 360MB/s]
# Downloading (…)of-00003.safetensors:  39%|▊ | 3.89G/9.90G [00:11<00:16, 363MB/s]
# Downloading (…)of-00003.safetensors:  40%|▊ | 3.93G/9.90G [00:11<00:17, 345MB/s]
# Downloading (…)of-00003.safetensors:  40%|▊ | 3.97G/9.90G [00:11<00:17, 340MB/s]
# Downloading (…)of-00003.safetensors:  41%|▊ | 4.02G/9.90G [00:11<00:16, 353MB/s]
# Downloading (…)of-00003.safetensors:  41%|▊ | 4.06G/9.90G [00:11<00:16, 362MB/s]
# Downloading (…)of-00003.safetensors:  41%|▊ | 4.10G/9.90G [00:11<00:16, 362MB/s]
# Downloading (…)of-00003.safetensors:  42%|▊ | 4.14G/9.90G [00:11<00:15, 367MB/s]
# Downloading (…)of-00003.safetensors:  42%|▊ | 4.18G/9.90G [00:11<00:15, 362MB/s]
# Downloading (…)of-00003.safetensors:  43%|▊ | 4.23G/9.90G [00:11<00:15, 368MB/s]
# Downloading (…)of-00003.safetensors:  43%|▊ | 4.27G/9.90G [00:12<00:15, 370MB/s]
# Downloading (…)of-00003.safetensors:  44%|▊ | 4.31G/9.90G [00:12<00:15, 363MB/s]
# Downloading (…)of-00003.safetensors:  44%|▉ | 4.35G/9.90G [00:12<00:15, 369MB/s]
# Downloading (…)of-00003.safetensors:  44%|▉ | 4.39G/9.90G [00:12<00:14, 373MB/s]
# Downloading (…)of-00003.safetensors:  45%|▉ | 4.44G/9.90G [00:12<00:14, 372MB/s]
# Downloading (…)of-00003.safetensors:  45%|▉ | 4.48G/9.90G [00:12<00:14, 375MB/s]
# Downloading (…)of-00003.safetensors:  46%|▉ | 4.52G/9.90G [00:12<00:14, 376MB/s]
# Downloading (…)of-00003.safetensors:  46%|▉ | 4.56G/9.90G [00:12<00:14, 378MB/s]
# Downloading (…)of-00003.safetensors:  46%|▉ | 4.60G/9.90G [00:12<00:14, 374MB/s]
# Downloading (…)of-00003.safetensors:  47%|▉ | 4.65G/9.90G [00:13<00:14, 375MB/s]
# Downloading (…)of-00003.safetensors:  47%|▉ | 4.69G/9.90G [00:13<00:13, 374MB/s]
# Downloading (…)of-00003.safetensors:  48%|▉ | 4.73G/9.90G [00:13<00:13, 372MB/s]
# Downloading (…)of-00003.safetensors:  48%|▉ | 4.77G/9.90G [00:13<00:13, 374MB/s]
# Downloading (…)of-00003.safetensors:  49%|▉ | 4.81G/9.90G [00:13<00:13, 374MB/s]
# Downloading (…)of-00003.safetensors:  49%|▉ | 4.85G/9.90G [00:13<00:13, 375MB/s]
# Downloading (…)of-00003.safetensors:  49%|▉ | 4.90G/9.90G [00:13<00:13, 373MB/s]
# Downloading (…)of-00003.safetensors:  50%|▉ | 4.94G/9.90G [00:13<00:13, 374MB/s]
# Downloading (…)of-00003.safetensors:  50%|█ | 4.98G/9.90G [00:13<00:13, 374MB/s]
# Downloading (…)of-00003.safetensors:  51%|█ | 5.02G/9.90G [00:14<00:13, 369MB/s]
# Downloading (…)of-00003.safetensors:  51%|█ | 5.06G/9.90G [00:14<00:12, 374MB/s]
# Downloading (…)of-00003.safetensors:  52%|█ | 5.11G/9.90G [00:14<00:12, 375MB/s]
# Downloading (…)of-00003.safetensors:  52%|█ | 5.15G/9.90G [00:14<00:12, 376MB/s]
# Downloading (…)of-00003.safetensors:  52%|█ | 5.19G/9.90G [00:14<00:12, 376MB/s]
# Downloading (…)of-00003.safetensors:  53%|█ | 5.23G/9.90G [00:14<00:12, 378MB/s]
# Downloading (…)of-00003.safetensors:  53%|█ | 5.27G/9.90G [00:14<00:12, 375MB/s]
# Downloading (…)of-00003.safetensors:  54%|█ | 5.32G/9.90G [00:14<00:12, 378MB/s]
# Downloading (…)of-00003.safetensors:  54%|█ | 5.36G/9.90G [00:14<00:11, 381MB/s]
# Downloading (…)of-00003.safetensors:  55%|█ | 5.40G/9.90G [00:15<00:11, 380MB/s]
# Downloading (…)of-00003.safetensors:  55%|█ | 5.44G/9.90G [00:15<00:11, 380MB/s]
# Downloading (…)of-00003.safetensors:  55%|█ | 5.48G/9.90G [00:15<00:11, 379MB/s]
# Downloading (…)of-00003.safetensors:  56%|█ | 5.53G/9.90G [00:15<00:11, 381MB/s]
# Downloading (…)of-00003.safetensors:  56%|█ | 5.57G/9.90G [00:15<00:11, 381MB/s]
# Downloading (…)of-00003.safetensors:  57%|█▏| 5.61G/9.90G [00:15<00:11, 382MB/s]
# Downloading (…)of-00003.safetensors:  57%|█▏| 5.65G/9.90G [00:15<00:11, 380MB/s]
# Downloading (…)of-00003.safetensors:  57%|█▏| 5.69G/9.90G [00:15<00:11, 375MB/s]
# Downloading (…)of-00003.safetensors:  58%|█▏| 5.74G/9.90G [00:15<00:11, 376MB/s]
# Downloading (…)of-00003.safetensors:  58%|█▏| 5.78G/9.90G [00:16<00:11, 375MB/s]
# Downloading (…)of-00003.safetensors:  59%|█▏| 5.82G/9.90G [00:16<00:11, 361MB/s]
# Downloading (…)of-00003.safetensors:  59%|█▏| 5.86G/9.90G [00:16<00:11, 361MB/s]
# Downloading (…)of-00003.safetensors:  60%|█▏| 5.90G/9.90G [00:16<00:10, 366MB/s]
# Downloading (…)of-00003.safetensors:  60%|█▏| 5.95G/9.90G [00:16<00:10, 371MB/s]
# Downloading (…)of-00003.safetensors:  60%|█▏| 5.99G/9.90G [00:16<00:10, 373MB/s]
# Downloading (…)of-00003.safetensors:  61%|█▏| 6.03G/9.90G [00:16<00:10, 377MB/s]
# Downloading (…)of-00003.safetensors:  61%|█▏| 6.07G/9.90G [00:16<00:10, 380MB/s]
# Downloading (…)of-00003.safetensors:  62%|█▏| 6.11G/9.90G [00:16<00:09, 382MB/s]
# Downloading (…)of-00003.safetensors:  62%|█▏| 6.16G/9.90G [00:17<00:09, 384MB/s]
# Downloading (…)of-00003.safetensors:  63%|█▎| 6.20G/9.90G [00:17<00:09, 386MB/s]
# Downloading (…)of-00003.safetensors:  63%|█▎| 6.24G/9.90G [00:17<00:09, 374MB/s]
# Downloading (…)of-00003.safetensors:  63%|█▎| 6.28G/9.90G [00:17<00:09, 375MB/s]
# Downloading (…)of-00003.safetensors:  64%|█▎| 6.32G/9.90G [00:17<00:09, 378MB/s]
# Downloading (…)of-00003.safetensors:  64%|█▎| 6.36G/9.90G [00:17<00:09, 380MB/s]
# Downloading (…)of-00003.safetensors:  65%|█▎| 6.41G/9.90G [00:17<00:09, 384MB/s]
# Downloading (…)of-00003.safetensors:  65%|█▎| 6.45G/9.90G [00:17<00:08, 385MB/s]
# Downloading (…)of-00003.safetensors:  66%|█▎| 6.49G/9.90G [00:17<00:08, 384MB/s]
# Downloading (…)of-00003.safetensors:  66%|█▎| 6.53G/9.90G [00:18<00:08, 387MB/s]
# Downloading (…)of-00003.safetensors:  66%|█▎| 6.57G/9.90G [00:18<00:08, 387MB/s]
# Downloading (…)of-00003.safetensors:  67%|█▎| 6.62G/9.90G [00:18<00:08, 380MB/s]
# Downloading (…)of-00003.safetensors:  67%|█▎| 6.66G/9.90G [00:18<00:08, 382MB/s]
# Downloading (…)of-00003.safetensors:  68%|█▎| 6.70G/9.90G [00:18<00:08, 383MB/s]
# Downloading (…)of-00003.safetensors:  68%|█▎| 6.74G/9.90G [00:18<00:08, 381MB/s]
# Downloading (…)of-00003.safetensors:  68%|█▎| 6.78G/9.90G [00:18<00:08, 380MB/s]
# Downloading (…)of-00003.safetensors:  69%|█▍| 6.83G/9.90G [00:18<00:08, 382MB/s]
# Downloading (…)of-00003.safetensors:  69%|█▍| 6.87G/9.90G [00:18<00:08, 376MB/s]
# Downloading (…)of-00003.safetensors:  70%|█▍| 6.91G/9.90G [00:19<00:07, 375MB/s]
# Downloading (…)of-00003.safetensors:  70%|█▍| 6.95G/9.90G [00:19<00:07, 372MB/s]
# Downloading (…)of-00003.safetensors:  71%|█▍| 6.99G/9.90G [00:19<00:07, 376MB/s]
# Downloading (…)of-00003.safetensors:  71%|█▍| 7.04G/9.90G [00:19<00:07, 375MB/s]
# Downloading (…)of-00003.safetensors:  71%|█▍| 7.08G/9.90G [00:19<00:07, 378MB/s]
# Downloading (…)of-00003.safetensors:  72%|█▍| 7.12G/9.90G [00:19<00:07, 381MB/s]
# Downloading (…)of-00003.safetensors:  72%|█▍| 7.16G/9.90G [00:19<00:07, 381MB/s]
# Downloading (…)of-00003.safetensors:  73%|█▍| 7.20G/9.90G [00:19<00:07, 382MB/s]
# Downloading (…)of-00003.safetensors:  73%|█▍| 7.25G/9.90G [00:19<00:06, 383MB/s]
# Downloading (…)of-00003.safetensors:  74%|█▍| 7.29G/9.90G [00:20<00:06, 374MB/s]
# Downloading (…)of-00003.safetensors:  74%|█▍| 7.33G/9.90G [00:20<00:09, 284MB/s]
# Downloading (…)of-00003.safetensors:  74%|█▍| 7.37G/9.90G [00:20<00:08, 309MB/s]
# Downloading (…)of-00003.safetensors:  75%|█▍| 7.41G/9.90G [00:20<00:07, 325MB/s]
# Downloading (…)of-00003.safetensors:  75%|█▌| 7.46G/9.90G [00:20<00:07, 340MB/s]
# Downloading (…)of-00003.safetensors:  76%|█▌| 7.50G/9.90G [00:20<00:07, 343MB/s]
# Downloading (…)of-00003.safetensors:  76%|█▌| 7.54G/9.90G [00:20<00:06, 353MB/s]
# Downloading (…)of-00003.safetensors:  77%|█▌| 7.58G/9.90G [00:20<00:06, 361MB/s]
# Downloading (…)of-00003.safetensors:  77%|█▌| 7.62G/9.90G [00:21<00:06, 368MB/s]
# Downloading (…)of-00003.safetensors:  77%|█▌| 7.67G/9.90G [00:21<00:05, 376MB/s]
# Downloading (…)of-00003.safetensors:  78%|█▌| 7.71G/9.90G [00:21<00:05, 378MB/s]
# Downloading (…)of-00003.safetensors:  78%|█▌| 7.75G/9.90G [00:21<00:05, 381MB/s]
# Downloading (…)of-00003.safetensors:  79%|█▌| 7.79G/9.90G [00:21<00:05, 375MB/s]
# Downloading (…)of-00003.safetensors:  79%|█▌| 7.83G/9.90G [00:21<00:05, 379MB/s]
# Downloading (…)of-00003.safetensors:  80%|█▌| 7.87G/9.90G [00:21<00:05, 383MB/s]
# Downloading (…)of-00003.safetensors:  80%|█▌| 7.92G/9.90G [00:21<00:05, 386MB/s]
# Downloading (…)of-00003.safetensors:  80%|█▌| 7.96G/9.90G [00:21<00:05, 386MB/s]
# Downloading (…)of-00003.safetensors:  81%|█▌| 8.00G/9.90G [00:22<00:04, 388MB/s]
# Downloading (…)of-00003.safetensors:  81%|█▌| 8.04G/9.90G [00:22<00:04, 384MB/s]
# Downloading (…)of-00003.safetensors:  82%|█▋| 8.08G/9.90G [00:22<00:04, 385MB/s]
# Downloading (…)of-00003.safetensors:  82%|█▋| 8.13G/9.90G [00:22<00:04, 387MB/s]
# Downloading (…)of-00003.safetensors:  82%|█▋| 8.17G/9.90G [00:22<00:04, 389MB/s]
# Downloading (…)of-00003.safetensors:  83%|█▋| 8.21G/9.90G [00:22<00:04, 390MB/s]
# Downloading (…)of-00003.safetensors:  83%|█▋| 8.25G/9.90G [00:22<00:04, 384MB/s]
# Downloading (…)of-00003.safetensors:  84%|█▋| 8.29G/9.90G [00:22<00:04, 388MB/s]
# Downloading (…)of-00003.safetensors:  84%|█▋| 8.34G/9.90G [00:22<00:04, 390MB/s]
# Downloading (…)of-00003.safetensors:  85%|█▋| 8.38G/9.90G [00:23<00:03, 387MB/s]
# Downloading (…)of-00003.safetensors:  85%|█▋| 8.42G/9.90G [00:23<00:04, 368MB/s]
# Downloading (…)of-00003.safetensors:  85%|█▋| 8.46G/9.90G [00:23<00:04, 349MB/s]
# Downloading (…)of-00003.safetensors:  86%|█▋| 8.50G/9.90G [00:23<00:04, 342MB/s]
# Downloading (…)of-00003.safetensors:  86%|█▋| 8.55G/9.90G [00:23<00:03, 341MB/s]
# Downloading (…)of-00003.safetensors:  87%|█▋| 8.59G/9.90G [00:23<00:03, 352MB/s]
# Downloading (…)of-00003.safetensors:  87%|█▋| 8.63G/9.90G [00:23<00:03, 362MB/s]
# Downloading (…)of-00003.safetensors:  88%|█▊| 8.67G/9.90G [00:23<00:03, 368MB/s]
# Downloading (…)of-00003.safetensors:  88%|█▊| 8.71G/9.90G [00:23<00:03, 376MB/s]
# Downloading (…)of-00003.safetensors:  88%|█▊| 8.76G/9.90G [00:24<00:03, 380MB/s]
# Downloading (…)of-00003.safetensors:  89%|█▊| 8.80G/9.90G [00:24<00:02, 385MB/s]
# Downloading (…)of-00003.safetensors:  89%|█▊| 8.84G/9.90G [00:24<00:02, 387MB/s]
# Downloading (…)of-00003.safetensors:  90%|█▊| 8.88G/9.90G [00:24<00:02, 378MB/s]
# Downloading (…)of-00003.safetensors:  90%|█▊| 8.92G/9.90G [00:24<00:02, 372MB/s]
# Downloading (…)of-00003.safetensors:  91%|█▊| 8.97G/9.90G [00:24<00:02, 379MB/s]
# Downloading (…)of-00003.safetensors:  91%|█▊| 9.01G/9.90G [00:24<00:02, 385MB/s]
# Downloading (…)of-00003.safetensors:  91%|█▊| 9.05G/9.90G [00:24<00:02, 386MB/s]
# Downloading (…)of-00003.safetensors:  92%|█▊| 9.09G/9.90G [00:24<00:02, 358MB/s]
# Downloading (…)of-00003.safetensors:  92%|█▊| 9.13G/9.90G [00:25<00:02, 367MB/s]
# Downloading (…)of-00003.safetensors:  93%|█▊| 9.18G/9.90G [00:25<00:01, 374MB/s]
# Downloading (…)of-00003.safetensors:  93%|█▊| 9.22G/9.90G [00:25<00:01, 358MB/s]
# Downloading (…)of-00003.safetensors:  93%|█▊| 9.26G/9.90G [00:25<00:01, 346MB/s]
# Downloading (…)of-00003.safetensors:  94%|█▉| 9.30G/9.90G [00:25<00:01, 356MB/s]
# Downloading (…)of-00003.safetensors:  94%|█▉| 9.34G/9.90G [00:25<00:01, 362MB/s]
# Downloading (…)of-00003.safetensors:  95%|█▉| 9.38G/9.90G [00:25<00:01, 369MB/s]
# Downloading (…)of-00003.safetensors:  95%|█▉| 9.43G/9.90G [00:25<00:01, 371MB/s]
# Downloading (…)of-00003.safetensors:  96%|█▉| 9.47G/9.90G [00:26<00:01, 373MB/s]
# Downloading (…)of-00003.safetensors:  96%|█▉| 9.51G/9.90G [00:26<00:01, 371MB/s]
# Downloading (…)of-00003.safetensors:  96%|█▉| 9.55G/9.90G [00:26<00:00, 372MB/s]
# Downloading (…)of-00003.safetensors:  97%|█▉| 9.59G/9.90G [00:26<00:00, 376MB/s]
# Downloading (…)of-00003.safetensors:  97%|█▉| 9.64G/9.90G [00:26<00:00, 377MB/s]
# Downloading (…)of-00003.safetensors:  98%|█▉| 9.68G/9.90G [00:26<00:00, 378MB/s]
# Downloading (…)of-00003.safetensors:  98%|█▉| 9.72G/9.90G [00:26<00:00, 374MB/s]
# Downloading (…)of-00003.safetensors:  99%|█▉| 9.76G/9.90G [00:26<00:00, 377MB/s]
# Downloading (…)of-00003.safetensors:  99%|█▉| 9.80G/9.90G [00:26<00:00, 376MB/s]
# Downloading (…)of-00003.safetensors:  99%|█▉| 9.85G/9.90G [00:27<00:00, 378MB/s]
# Downloading (…)of-00003.safetensors: 100%|██| 9.90G/9.90G [00:27<00:00, 364MB/s]
# Downloading shards:  67%|████████████████▋        | 2/3 [00:55<00:27, 27.63s/it]
# Downloading (…)of-00003.safetensors:   0%|          | 0.00/6.18G [00:00<?, ?B/s]
# Downloading (…)of-00003.safetensors:   1%|  | 41.9M/6.18G [00:00<00:15, 394MB/s]
# Downloading (…)of-00003.safetensors:   1%|  | 83.9M/6.18G [00:00<00:16, 375MB/s]
# Downloading (…)of-00003.safetensors:   2%|   | 126M/6.18G [00:00<00:15, 379MB/s]
# Downloading (…)of-00003.safetensors:   3%|   | 168M/6.18G [00:00<00:15, 383MB/s]
# Downloading (…)of-00003.safetensors:   3%|   | 210M/6.18G [00:00<00:15, 378MB/s]
# Downloading (…)of-00003.safetensors:   4%|   | 252M/6.18G [00:00<00:15, 375MB/s]
# Downloading (…)of-00003.safetensors:   5%|▏  | 294M/6.18G [00:00<00:15, 379MB/s]
# Downloading (…)of-00003.safetensors:   5%|▏  | 336M/6.18G [00:00<00:16, 362MB/s]
# Downloading (…)of-00003.safetensors:   6%|▏  | 377M/6.18G [00:01<00:15, 367MB/s]
# Downloading (…)of-00003.safetensors:   7%|▏  | 419M/6.18G [00:01<00:15, 373MB/s]
# Downloading (…)of-00003.safetensors:   7%|▏  | 461M/6.18G [00:01<00:15, 376MB/s]
# Downloading (…)of-00003.safetensors:   8%|▏  | 503M/6.18G [00:01<00:15, 377MB/s]
# Downloading (…)of-00003.safetensors:   9%|▎  | 545M/6.18G [00:01<00:14, 379MB/s]
# Downloading (…)of-00003.safetensors:  10%|▎  | 587M/6.18G [00:01<00:14, 376MB/s]
# Downloading (…)of-00003.safetensors:  10%|▎  | 629M/6.18G [00:01<00:14, 380MB/s]
# Downloading (…)of-00003.safetensors:  11%|▎  | 671M/6.18G [00:01<00:14, 380MB/s]
# Downloading (…)of-00003.safetensors:  12%|▎  | 713M/6.18G [00:01<00:14, 380MB/s]
# Downloading (…)of-00003.safetensors:  12%|▎  | 755M/6.18G [00:02<00:14, 380MB/s]
# Downloading (…)of-00003.safetensors:  13%|▍  | 797M/6.18G [00:02<00:21, 251MB/s]
# Downloading (…)of-00003.safetensors:  14%|▍  | 839M/6.18G [00:02<00:19, 280MB/s]
# Downloading (…)of-00003.safetensors:  14%|▍  | 881M/6.18G [00:02<00:17, 305MB/s]
# Downloading (…)of-00003.safetensors:  15%|▍  | 923M/6.18G [00:02<00:16, 321MB/s]
# Downloading (…)of-00003.safetensors:  16%|▍  | 965M/6.18G [00:02<00:15, 338MB/s]
# Downloading (…)of-00003.safetensors:  16%|▎ | 1.01G/6.18G [00:02<00:14, 351MB/s]
# Downloading (…)of-00003.safetensors:  17%|▎ | 1.05G/6.18G [00:02<00:14, 359MB/s]
# Downloading (…)of-00003.safetensors:  18%|▎ | 1.09G/6.18G [00:03<00:13, 366MB/s]
# Downloading (…)of-00003.safetensors:  18%|▎ | 1.13G/6.18G [00:03<00:13, 362MB/s]
# Downloading (…)of-00003.safetensors:  19%|▍ | 1.17G/6.18G [00:03<00:14, 353MB/s]
# Downloading (…)of-00003.safetensors:  20%|▍ | 1.22G/6.18G [00:03<00:14, 351MB/s]
# Downloading (…)of-00003.safetensors:  20%|▍ | 1.26G/6.18G [00:03<00:13, 356MB/s]
# Downloading (…)of-00003.safetensors:  21%|▍ | 1.30G/6.18G [00:03<00:13, 361MB/s]
# Downloading (…)of-00003.safetensors:  22%|▍ | 1.34G/6.18G [00:03<00:13, 366MB/s]
# Downloading (…)of-00003.safetensors:  22%|▍ | 1.38G/6.18G [00:03<00:12, 370MB/s]
# Downloading (…)of-00003.safetensors:  23%|▍ | 1.43G/6.18G [00:03<00:12, 374MB/s]
# Downloading (…)of-00003.safetensors:  24%|▍ | 1.47G/6.18G [00:04<00:12, 376MB/s]
# Downloading (…)of-00003.safetensors:  24%|▍ | 1.51G/6.18G [00:04<00:12, 374MB/s]
# Downloading (…)of-00003.safetensors:  25%|▌ | 1.55G/6.18G [00:04<00:12, 370MB/s]
# Downloading (…)of-00003.safetensors:  26%|▌ | 1.59G/6.18G [00:04<00:12, 374MB/s]
# Downloading (…)of-00003.safetensors:  26%|▌ | 1.64G/6.18G [00:04<00:12, 374MB/s]
# Downloading (…)of-00003.safetensors:  27%|▌ | 1.68G/6.18G [00:04<00:11, 379MB/s]
# Downloading (…)of-00003.safetensors:  28%|▌ | 1.72G/6.18G [00:04<00:11, 376MB/s]
# Downloading (…)of-00003.safetensors:  29%|▌ | 1.76G/6.18G [00:04<00:12, 368MB/s]
# Downloading (…)of-00003.safetensors:  29%|▌ | 1.80G/6.18G [00:05<00:11, 367MB/s]
# Downloading (…)of-00003.safetensors:  30%|▌ | 1.85G/6.18G [00:05<00:11, 367MB/s]
# Downloading (…)of-00003.safetensors:  31%|▌ | 1.89G/6.18G [00:05<00:11, 372MB/s]
# Downloading (…)of-00003.safetensors:  31%|▌ | 1.93G/6.18G [00:05<00:11, 374MB/s]
# Downloading (…)of-00003.safetensors:  32%|▋ | 1.97G/6.18G [00:05<00:11, 352MB/s]
# Downloading (…)of-00003.safetensors:  33%|▋ | 2.01G/6.18G [00:05<00:12, 329MB/s]
# Downloading (…)of-00003.safetensors:  33%|▋ | 2.06G/6.18G [00:05<00:12, 339MB/s]
# Downloading (…)of-00003.safetensors:  34%|▋ | 2.10G/6.18G [00:05<00:11, 348MB/s]
# Downloading (…)of-00003.safetensors:  35%|▋ | 2.14G/6.18G [00:05<00:11, 352MB/s]
# Downloading (…)of-00003.safetensors:  35%|▋ | 2.18G/6.18G [00:06<00:11, 357MB/s]
# Downloading (…)of-00003.safetensors:  36%|▋ | 2.22G/6.18G [00:06<00:10, 364MB/s]
# Downloading (…)of-00003.safetensors:  37%|▋ | 2.26G/6.18G [00:06<00:10, 368MB/s]
# Downloading (…)of-00003.safetensors:  37%|▋ | 2.31G/6.18G [00:06<00:10, 370MB/s]
# Downloading (…)of-00003.safetensors:  38%|▊ | 2.35G/6.18G [00:06<00:10, 373MB/s]
# Downloading (…)of-00003.safetensors:  39%|▊ | 2.39G/6.18G [00:06<00:10, 376MB/s]
# Downloading (…)of-00003.safetensors:  39%|▊ | 2.43G/6.18G [00:06<00:09, 378MB/s]
# Downloading (…)of-00003.safetensors:  40%|▊ | 2.47G/6.18G [00:06<00:09, 380MB/s]
# Downloading (…)of-00003.safetensors:  41%|▊ | 2.52G/6.18G [00:06<00:09, 382MB/s]
# Downloading (…)of-00003.safetensors:  41%|▊ | 2.56G/6.18G [00:07<00:09, 378MB/s]
# Downloading (…)of-00003.safetensors:  42%|▊ | 2.60G/6.18G [00:07<00:10, 356MB/s]
# Downloading (…)of-00003.safetensors:  43%|▊ | 2.64G/6.18G [00:07<00:09, 354MB/s]
# Downloading (…)of-00003.safetensors:  43%|▊ | 2.68G/6.18G [00:07<00:09, 362MB/s]
# Downloading (…)of-00003.safetensors:  44%|▉ | 2.73G/6.18G [00:07<00:09, 359MB/s]
# Downloading (…)of-00003.safetensors:  45%|▉ | 2.77G/6.18G [00:07<00:09, 363MB/s]
# Downloading (…)of-00003.safetensors:  45%|▉ | 2.81G/6.18G [00:07<00:09, 366MB/s]
# Downloading (…)of-00003.safetensors:  46%|▉ | 2.85G/6.18G [00:07<00:09, 358MB/s]
# Downloading (…)of-00003.safetensors:  47%|▉ | 2.89G/6.18G [00:08<00:09, 353MB/s]
# Downloading (…)of-00003.safetensors:  48%|▉ | 2.94G/6.18G [00:08<00:09, 329MB/s]
# Downloading (…)of-00003.safetensors:  48%|▉ | 2.98G/6.18G [00:08<00:09, 340MB/s]
# Downloading (…)of-00003.safetensors:  49%|▉ | 3.02G/6.18G [00:08<00:09, 350MB/s]
# Downloading (…)of-00003.safetensors:  50%|▉ | 3.06G/6.18G [00:08<00:08, 359MB/s]
# Downloading (…)of-00003.safetensors:  50%|█ | 3.10G/6.18G [00:08<00:08, 365MB/s]
# Downloading (…)of-00003.safetensors:  51%|█ | 3.15G/6.18G [00:08<00:09, 337MB/s]
# Downloading (…)of-00003.safetensors:  52%|█ | 3.19G/6.18G [00:08<00:08, 347MB/s]
# Downloading (…)of-00003.safetensors:  52%|█ | 3.23G/6.18G [00:08<00:08, 357MB/s]
# Downloading (…)of-00003.safetensors:  53%|█ | 3.27G/6.18G [00:09<00:08, 361MB/s]
# Downloading (…)of-00003.safetensors:  54%|█ | 3.31G/6.18G [00:09<00:07, 367MB/s]
# Downloading (…)of-00003.safetensors:  54%|█ | 3.36G/6.18G [00:09<00:07, 361MB/s]
# Downloading (…)of-00003.safetensors:  55%|█ | 3.40G/6.18G [00:09<00:07, 365MB/s]
# Downloading (…)of-00003.safetensors:  56%|█ | 3.44G/6.18G [00:09<00:07, 367MB/s]
# Downloading (…)of-00003.safetensors:  56%|█▏| 3.48G/6.18G [00:09<00:07, 368MB/s]
# Downloading (…)of-00003.safetensors:  57%|█▏| 3.52G/6.18G [00:09<00:07, 369MB/s]
# Downloading (…)of-00003.safetensors:  58%|█▏| 3.57G/6.18G [00:09<00:07, 358MB/s]
# Downloading (…)of-00003.safetensors:  58%|█▏| 3.61G/6.18G [00:10<00:07, 356MB/s]
# Downloading (…)of-00003.safetensors:  59%|█▏| 3.65G/6.18G [00:10<00:06, 362MB/s]
# Downloading (…)of-00003.safetensors:  60%|█▏| 3.69G/6.18G [00:10<00:06, 367MB/s]
# Downloading (…)of-00003.safetensors:  60%|█▏| 3.73G/6.18G [00:10<00:06, 369MB/s]
# Downloading (…)of-00003.safetensors:  61%|█▏| 3.77G/6.18G [00:10<00:06, 373MB/s]
# Downloading (…)of-00003.safetensors:  62%|█▏| 3.82G/6.18G [00:10<00:06, 374MB/s]
# Downloading (…)of-00003.safetensors:  62%|█▏| 3.86G/6.18G [00:10<00:06, 376MB/s]
# Downloading (…)of-00003.safetensors:  63%|█▎| 3.90G/6.18G [00:10<00:06, 377MB/s]
# Downloading (…)of-00003.safetensors:  64%|█▎| 3.94G/6.18G [00:10<00:05, 379MB/s]
# Downloading (…)of-00003.safetensors:  64%|█▎| 3.98G/6.18G [00:11<00:05, 380MB/s]
# Downloading (…)of-00003.safetensors:  65%|█▎| 4.03G/6.18G [00:11<00:05, 381MB/s]
# Downloading (…)of-00003.safetensors:  66%|█▎| 4.07G/6.18G [00:11<00:05, 380MB/s]
# Downloading (…)of-00003.safetensors:  67%|█▎| 4.11G/6.18G [00:11<00:05, 377MB/s]
# Downloading (…)of-00003.safetensors:  67%|█▎| 4.15G/6.18G [00:11<00:05, 377MB/s]
# Downloading (…)of-00003.safetensors:  68%|█▎| 4.19G/6.18G [00:11<00:05, 376MB/s]
# Downloading (…)of-00003.safetensors:  69%|█▎| 4.24G/6.18G [00:11<00:05, 373MB/s]
# Downloading (…)of-00003.safetensors:  69%|█▍| 4.28G/6.18G [00:11<00:05, 376MB/s]
# Downloading (…)of-00003.safetensors:  70%|█▍| 4.32G/6.18G [00:11<00:04, 378MB/s]
# Downloading (…)of-00003.safetensors:  71%|█▍| 4.36G/6.18G [00:12<00:04, 379MB/s]
# Downloading (…)of-00003.safetensors:  71%|█▍| 4.40G/6.18G [00:12<00:04, 381MB/s]
# Downloading (…)of-00003.safetensors:  72%|█▍| 4.45G/6.18G [00:12<00:04, 382MB/s]
# Downloading (…)of-00003.safetensors:  73%|█▍| 4.49G/6.18G [00:12<00:04, 379MB/s]
# Downloading (…)of-00003.safetensors:  73%|█▍| 4.53G/6.18G [00:12<00:04, 380MB/s]
# Downloading (…)of-00003.safetensors:  74%|█▍| 4.57G/6.18G [00:12<00:04, 372MB/s]
# Downloading (…)of-00003.safetensors:  75%|█▍| 4.61G/6.18G [00:12<00:04, 363MB/s]
# Downloading (…)of-00003.safetensors:  75%|█▌| 4.66G/6.18G [00:12<00:04, 356MB/s]
# Downloading (…)of-00003.safetensors:  76%|█▌| 4.70G/6.18G [00:12<00:04, 357MB/s]
# Downloading (…)of-00003.safetensors:  77%|█▌| 4.74G/6.18G [00:13<00:03, 362MB/s]
# Downloading (…)of-00003.safetensors:  77%|█▌| 4.78G/6.18G [00:13<00:03, 368MB/s]
# Downloading (…)of-00003.safetensors:  78%|█▌| 4.82G/6.18G [00:13<00:03, 367MB/s]
# Downloading (…)of-00003.safetensors:  79%|█▌| 4.87G/6.18G [00:13<00:03, 360MB/s]
# Downloading (…)of-00003.safetensors:  79%|█▌| 4.91G/6.18G [00:13<00:03, 331MB/s]
# Downloading (…)of-00003.safetensors:  80%|█▌| 4.95G/6.18G [00:13<00:03, 344MB/s]
# Downloading (…)of-00003.safetensors:  81%|█▌| 4.99G/6.18G [00:13<00:03, 352MB/s]
# Downloading (…)of-00003.safetensors:  81%|█▋| 5.03G/6.18G [00:13<00:03, 350MB/s]
# Downloading (…)of-00003.safetensors:  82%|█▋| 5.08G/6.18G [00:14<00:03, 357MB/s]
# Downloading (…)of-00003.safetensors:  83%|█▋| 5.12G/6.18G [00:14<00:02, 364MB/s]
# Downloading (…)of-00003.safetensors:  83%|█▋| 5.16G/6.18G [00:14<00:02, 364MB/s]
# Downloading (…)of-00003.safetensors:  84%|█▋| 5.20G/6.18G [00:14<00:02, 368MB/s]
# Downloading (…)of-00003.safetensors:  85%|█▋| 5.24G/6.18G [00:14<00:02, 372MB/s]
# Downloading (…)of-00003.safetensors:  86%|█▋| 5.28G/6.18G [00:14<00:02, 373MB/s]
# Downloading (…)of-00003.safetensors:  86%|█▋| 5.33G/6.18G [00:14<00:02, 374MB/s]
# Downloading (…)of-00003.safetensors:  87%|█▋| 5.37G/6.18G [00:14<00:02, 375MB/s]
# Downloading (…)of-00003.safetensors:  88%|█▊| 5.41G/6.18G [00:14<00:02, 369MB/s]
# Downloading (…)of-00003.safetensors:  88%|█▊| 5.45G/6.18G [00:15<00:01, 372MB/s]
# Downloading (…)of-00003.safetensors:  89%|█▊| 5.49G/6.18G [00:15<00:01, 375MB/s]
# Downloading (…)of-00003.safetensors:  90%|█▊| 5.54G/6.18G [00:15<00:01, 374MB/s]
# Downloading (…)of-00003.safetensors:  90%|█▊| 5.58G/6.18G [00:15<00:01, 363MB/s]
# Downloading (…)of-00003.safetensors:  91%|█▊| 5.62G/6.18G [00:15<00:01, 280MB/s]
# Downloading (…)of-00003.safetensors:  92%|█▊| 5.66G/6.18G [00:15<00:01, 300MB/s]
# Downloading (…)of-00003.safetensors:  92%|█▊| 5.70G/6.18G [00:15<00:01, 301MB/s]
# Downloading (…)of-00003.safetensors:  93%|█▊| 5.75G/6.18G [00:16<00:01, 295MB/s]
# Downloading (…)of-00003.safetensors:  94%|█▊| 5.79G/6.18G [00:16<00:01, 318MB/s]
# Downloading (…)of-00003.safetensors:  94%|█▉| 5.83G/6.18G [00:16<00:01, 331MB/s]
# Downloading (…)of-00003.safetensors:  95%|█▉| 5.87G/6.18G [00:16<00:00, 341MB/s]
# Downloading (…)of-00003.safetensors:  96%|█▉| 5.91G/6.18G [00:16<00:00, 348MB/s]
# Downloading (…)of-00003.safetensors:  96%|█▉| 5.96G/6.18G [00:16<00:00, 348MB/s]
# Downloading (…)of-00003.safetensors:  97%|█▉| 6.00G/6.18G [00:16<00:00, 313MB/s]
# Downloading (…)of-00003.safetensors:  98%|█▉| 6.04G/6.18G [00:16<00:00, 330MB/s]
# Downloading (…)of-00003.safetensors:  98%|█▉| 6.08G/6.18G [00:16<00:00, 346MB/s]
# Downloading (…)of-00003.safetensors:  99%|█▉| 6.12G/6.18G [00:17<00:00, 357MB/s]
# Downloading (…)of-00003.safetensors: 100%|██| 6.18G/6.18G [00:17<00:00, 359MB/s]
# Downloading shards: 100%|█████████████████████████| 3/3 [01:12<00:00, 24.24s/it]
# Loading checkpoint shards: 100%|██████████████████| 3/3 [00:03<00:00,  1.18s/it]
# Downloading (…)neration_config.json: 100%|█████| 188/188 [00:00<00:00, 2.77MB/s]
# Found 7 modules to quantize: ['k_proj', 'gate_proj', 'q_proj', 'o_proj', 'v_proj', 'up_proj', 'down_proj']
# trainable params: 250,347,520 || all params: 6,922,327,040 || trainable%: 3.6165225733108386
# /opt/conda/lib/python3.10/site-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# {'loss': 1.5702, 'learning_rate': 4.989458148850938e-05, 'epoch': 0.01}
# {'loss': 1.4527, 'learning_rate': 4.978916297701877e-05, 'epoch': 0.01}
# {'loss': 1.3838, 'learning_rate': 4.968374446552815e-05, 'epoch': 0.02}
# {'loss': 1.3312, 'learning_rate': 4.957832595403753e-05, 'epoch': 0.03}
# {'loss': 1.4338, 'learning_rate': 4.947290744254691e-05, 'epoch': 0.03}
# {'loss': 1.3887, 'learning_rate': 4.9367488931056297e-05, 'epoch': 0.04}
# {'loss': 1.449, 'learning_rate': 4.926207041956568e-05, 'epoch': 0.04}
# {'loss': 1.4625, 'learning_rate': 4.915665190807506e-05, 'epoch': 0.05}
# {'loss': 1.3182, 'learning_rate': 4.9051233396584444e-05, 'epoch': 0.06}
# {'loss': 1.3246, 'learning_rate': 4.8945814885093824e-05, 'epoch': 0.06}
# {'loss': 1.2651, 'learning_rate': 4.884039637360321e-05, 'epoch': 0.07}
# {'loss': 1.3459, 'learning_rate': 4.873497786211259e-05, 'epoch': 0.08}
# {'loss': 1.2931, 'learning_rate': 4.862955935062197e-05, 'epoch': 0.08}
# {'loss': 1.2706, 'learning_rate': 4.852414083913136e-05, 'epoch': 0.09}
# {'loss': 1.3184, 'learning_rate': 4.841872232764074e-05, 'epoch': 0.09}
# {'loss': 1.3985, 'learning_rate': 4.831330381615012e-05, 'epoch': 0.1}
# {'loss': 1.3598, 'learning_rate': 4.82078853046595e-05, 'epoch': 0.11}
# {'loss': 1.4073, 'learning_rate': 4.8102466793168885e-05, 'epoch': 0.11}
# {'loss': 1.3418, 'learning_rate': 4.7997048281678265e-05, 'epoch': 0.12}
# {'loss': 1.2706, 'learning_rate': 4.7891629770187645e-05, 'epoch': 0.13}
# {'loss': 1.4314, 'learning_rate': 4.7786211258697025e-05, 'epoch': 0.13}
# {'loss': 1.2817, 'learning_rate': 4.768079274720641e-05, 'epoch': 0.14}
# {'loss': 1.3045, 'learning_rate': 4.757537423571579e-05, 'epoch': 0.15}
# {'loss': 1.2846, 'learning_rate': 4.746995572422517e-05, 'epoch': 0.15}
# {'loss': 1.2929, 'learning_rate': 4.736453721273456e-05, 'epoch': 0.16}
# {'loss': 1.2348, 'learning_rate': 4.7259118701243946e-05, 'epoch': 0.16}
# {'loss': 1.1915, 'learning_rate': 4.7153700189753326e-05, 'epoch': 0.17}
# {'loss': 1.3854, 'learning_rate': 4.7048281678262706e-05, 'epoch': 0.18}
# {'loss': 1.3077, 'learning_rate': 4.6942863166772086e-05, 'epoch': 0.18}
# {'loss': 1.2537, 'learning_rate': 4.683744465528147e-05, 'epoch': 0.19}
# {'loss': 1.3399, 'learning_rate': 4.673202614379085e-05, 'epoch': 0.2}
# {'loss': 1.2907, 'learning_rate': 4.662660763230023e-05, 'epoch': 0.2}
# {'loss': 1.1502, 'learning_rate': 4.652118912080961e-05, 'epoch': 0.21}
# {'loss': 1.3361, 'learning_rate': 4.6415770609319e-05, 'epoch': 0.22}
# {'loss': 1.4415, 'learning_rate': 4.631035209782838e-05, 'epoch': 0.22}
# {'loss': 1.2476, 'learning_rate': 4.620493358633776e-05, 'epoch': 0.23}
# {'loss': 1.236, 'learning_rate': 4.609951507484714e-05, 'epoch': 0.23}
# {'loss': 1.235, 'learning_rate': 4.599409656335653e-05, 'epoch': 0.24}
# {'loss': 1.2955, 'learning_rate': 4.588867805186591e-05, 'epoch': 0.25}
# {'loss': 1.3898, 'learning_rate': 4.578325954037529e-05, 'epoch': 0.25}
# {'loss': 1.319, 'learning_rate': 4.5677841028884674e-05, 'epoch': 0.26}
# {'loss': 1.3626, 'learning_rate': 4.557242251739406e-05, 'epoch': 0.27}
# {'loss': 1.329, 'learning_rate': 4.546700400590344e-05, 'epoch': 0.27}
# {'loss': 1.2281, 'learning_rate': 4.536158549441282e-05, 'epoch': 0.28}
# {'loss': 1.1936, 'learning_rate': 4.52561669829222e-05, 'epoch': 0.28}
# {'loss': 1.2508, 'learning_rate': 4.515074847143159e-05, 'epoch': 0.29}
# {'loss': 1.3409, 'learning_rate': 4.504532995994097e-05, 'epoch': 0.3}
# {'loss': 1.3388, 'learning_rate': 4.493991144845035e-05, 'epoch': 0.3}
# {'loss': 1.2642, 'learning_rate': 4.4834492936959735e-05, 'epoch': 0.31}
# {'loss': 1.2661, 'learning_rate': 4.4729074425469116e-05, 'epoch': 0.32}
# {'loss': 1.2697, 'learning_rate': 4.4623655913978496e-05, 'epoch': 0.32}
# {'loss': 1.3731, 'learning_rate': 4.4518237402487876e-05, 'epoch': 0.33}
# {'loss': 1.2853, 'learning_rate': 4.441281889099726e-05, 'epoch': 0.34}
# {'loss': 1.3256, 'learning_rate': 4.430740037950664e-05, 'epoch': 0.34}
# {'loss': 1.4947, 'learning_rate': 4.420198186801602e-05, 'epoch': 0.35}
# {'loss': 1.3771, 'learning_rate': 4.40965633565254e-05, 'epoch': 0.35}
# {'loss': 1.3885, 'learning_rate': 4.399114484503479e-05, 'epoch': 0.36}
# {'loss': 1.358, 'learning_rate': 4.388572633354418e-05, 'epoch': 0.37}
# {'loss': 1.3055, 'learning_rate': 4.378030782205356e-05, 'epoch': 0.37}
# {'loss': 1.3897, 'learning_rate': 4.367488931056294e-05, 'epoch': 0.38}
# {'loss': 1.2578, 'learning_rate': 4.3569470799072324e-05, 'epoch': 0.39}
# {'loss': 1.4622, 'learning_rate': 4.3464052287581704e-05, 'epoch': 0.39}
# {'loss': 1.2206, 'learning_rate': 4.3358633776091084e-05, 'epoch': 0.4}
# {'loss': 1.4327, 'learning_rate': 4.3253215264600464e-05, 'epoch': 0.4}
# {'loss': 1.3995, 'learning_rate': 4.314779675310985e-05, 'epoch': 0.41}
# {'loss': 1.357, 'learning_rate': 4.304237824161923e-05, 'epoch': 0.42}
# {'loss': 1.2752, 'learning_rate': 4.293695973012861e-05, 'epoch': 0.42}
# {'loss': 1.3889, 'learning_rate': 4.283154121863799e-05, 'epoch': 0.43}
# {'loss': 1.3459, 'learning_rate': 4.272612270714738e-05, 'epoch': 0.44}
# {'loss': 1.3944, 'learning_rate': 4.262070419565676e-05, 'epoch': 0.44}
# {'loss': 1.4508, 'learning_rate': 4.251528568416614e-05, 'epoch': 0.45}
# {'loss': 1.4169, 'learning_rate': 4.240986717267552e-05, 'epoch': 0.46}
# {'loss': 1.4353, 'learning_rate': 4.2304448661184905e-05, 'epoch': 0.46}
# {'loss': 1.2957, 'learning_rate': 4.219903014969429e-05, 'epoch': 0.47}
# {'loss': 1.3254, 'learning_rate': 4.209361163820367e-05, 'epoch': 0.47}
# {'loss': 1.1438, 'learning_rate': 4.198819312671305e-05, 'epoch': 0.48}
# {'loss': 1.2363, 'learning_rate': 4.188277461522244e-05, 'epoch': 0.49}
# {'loss': 1.1736, 'learning_rate': 4.177735610373182e-05, 'epoch': 0.49}
# {'loss': 1.3303, 'learning_rate': 4.16719375922412e-05, 'epoch': 0.5}
# {'loss': 1.4611, 'learning_rate': 4.156651908075058e-05, 'epoch': 0.51}
# {'loss': 1.4434, 'learning_rate': 4.1461100569259966e-05, 'epoch': 0.51}
# {'loss': 1.2793, 'learning_rate': 4.1355682057769346e-05, 'epoch': 0.52}
# {'loss': 1.1593, 'learning_rate': 4.1250263546278726e-05, 'epoch': 0.52}
# {'loss': 1.1509, 'learning_rate': 4.1144845034788107e-05, 'epoch': 0.53}
# {'loss': 1.2182, 'learning_rate': 4.1039426523297493e-05, 'epoch': 0.54}
# {'loss': 1.3183, 'learning_rate': 4.0934008011806874e-05, 'epoch': 0.54}
# {'loss': 1.3037, 'learning_rate': 4.0828589500316254e-05, 'epoch': 0.55}
# {'loss': 1.3025, 'learning_rate': 4.072317098882564e-05, 'epoch': 0.56}
# {'loss': 1.3239, 'learning_rate': 4.061775247733502e-05, 'epoch': 0.56}
# {'loss': 1.5043, 'learning_rate': 4.051233396584441e-05, 'epoch': 0.57}
# {'loss': 1.2636, 'learning_rate': 4.040691545435379e-05, 'epoch': 0.58}
# {'loss': 1.2879, 'learning_rate': 4.030149694286317e-05, 'epoch': 0.58}
# {'loss': 1.2494, 'learning_rate': 4.0196078431372555e-05, 'epoch': 0.59}
# {'loss': 1.3575, 'learning_rate': 4.0090659919881935e-05, 'epoch': 0.59}
# {'loss': 1.285, 'learning_rate': 3.9985241408391315e-05, 'epoch': 0.6}
# {'loss': 1.2012, 'learning_rate': 3.9879822896900695e-05, 'epoch': 0.61}
# {'loss': 1.3532, 'learning_rate': 3.977440438541008e-05, 'epoch': 0.61}
# {'loss': 1.2027, 'learning_rate': 3.966898587391946e-05, 'epoch': 0.62}
# {'loss': 1.332, 'learning_rate': 3.956356736242884e-05, 'epoch': 0.63}
# {'loss': 1.0569, 'learning_rate': 3.945814885093823e-05, 'epoch': 0.63}
# {'loss': 1.1959, 'learning_rate': 3.935273033944761e-05, 'epoch': 0.64}
# {'loss': 1.4257, 'learning_rate': 3.924731182795699e-05, 'epoch': 0.65}
# {'loss': 1.3134, 'learning_rate': 3.914189331646637e-05, 'epoch': 0.65}
# {'loss': 1.3114, 'learning_rate': 3.9036474804975756e-05, 'epoch': 0.66}
# {'loss': 1.2408, 'learning_rate': 3.8931056293485136e-05, 'epoch': 0.66}
# {'loss': 1.3391, 'learning_rate': 3.882563778199452e-05, 'epoch': 0.67}
# {'loss': 1.3059, 'learning_rate': 3.87202192705039e-05, 'epoch': 0.68}
# {'loss': 1.2939, 'learning_rate': 3.861480075901329e-05, 'epoch': 0.68}
#  23%|████████                           | 1086/4743 [2:11:49<7:23:54,  7.28s/it]
